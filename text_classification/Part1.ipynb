# %%
import numpy as np
import pandas as pd

# %%
#PART1
#reading all the csv files and storing in dataframes
df_l0 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_0_lockdowns.csv")
df_l1 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_1_lockdowns.csv")
df_l2 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_2_lockdowns.csv")
df_l3 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_3_lockdowns.csv")
df_l4 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_4_lockdowns.csv")
df_m0 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_0_masking_and_distancing.csv")
df_m1 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_1_masking_and_distancing.csv")
df_m2 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_2_masking_and_distancing.csv")
df_m3 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_3_masking_and_distancing.csv")
df_m4 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_4_masking_and_distancing.csv")
df_v0 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_0_vaccination.csv")
df_v1 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_1_vaccination.csv")
df_v2 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_2_vaccination.csv")
df_v3 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_3_vaccination.csv")
df_v4 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_4_vaccination.csv")
tw_df_l0 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_0_lockdowns.csv")
tw_df_l1 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_1_lockdowns.csv")
tw_df_l2 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_2_lockdowns.csv")
tw_df_l3 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_3_lockdowns.csv")
tw_df_m0 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_0_masking_and_distancing.csv")
tw_df_m1 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_1_masking_and_distancing.csv")
tw_df_m2 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_2_masking_and_distancing.csv")
tw_df_m3 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_3_masking_and_distancing.csv")
tw_df_v0 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_0_vaccination.csv")
tw_df_v1 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_1_vaccination.csv")
tw_df_v2 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_2_vaccination.csv")
tw_df_v3 =  pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/twitter_topic_3_vaccination.csv")

# %%
df_l0.head()
# Out:
#                                                 text  annotation_96  \
# 0         Language Education in the Time of COVID-19          False
# 1                                 COVID-19 Test Kits          False
# 2                                 COVID 19 IN PRISON          False
# 3                                     Get Waled Home          False
# 4  Make pass/fail available for Mississippi State...          False
#
#    annotation_53  annotation_93  annotation_94  annotation_95
# 0          False          False          False          False
# 1          False          False          False          False
# 2          False          False          False          False
# 3          False          False          False          False
# 4          False          False          False          False

# %%
#sklearn.metrics.cohen_kappa_score(y1, y2, *, labels=None, weights=None, sample_weight=None)[source]¶

# %%
df_l0.shape
# Out:
# (300, 6)

# %%
df_l0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
# text             300 non-null object
# annotation_96    300 non-null bool
# annotation_53    300 non-null bool
# annotation_93    300 non-null bool
# annotation_94    300 non-null bool
# annotation_95    300 non-null bool
# dtypes: bool(5), object(1)
# memory usage: 3.9+ KB

# %%
df_l0.describe()
# Out:
#                                                      text annotation_96  \
# count                                                 300           300
# unique                                                300             2
# top     Yarra Valley should be classified as rural for...         False
# freq                                                    1           245
#
#        annotation_53 annotation_93 annotation_94 annotation_95
# count            300           300           300           300
# unique             2             2             2             2
# top            False         False         False         False
# freq             295           229           236           251

# %%
#import csv

#mydict = {}

#with open('/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_0_lockdowns.csv', mode='r') as inp:
#    reader = csv.reader(inp)
#    dict_from_csv = {rows[0]:rows[1] for rows in reader}

#print(dict_from_csv)

# %%
#storing annotators data in different variables
l_ann_96 = df_l0["annotation_96"]
l_ann_53 = df_l0["annotation_53"]
l_ann_93 = df_l0["annotation_93"]
l_ann_94 = df_l0["annotation_94"]
l_ann_95 = df_l0["annotation_95"]

# %%
#print(ann_53)
#Calculate cohen's kappa score for each annotator from each lockdown change.org files
from sklearn.metrics import cohen_kappa_score
kappa_lock_ann96_1 = cohen_kappa_score(l_ann_96, l_ann_53) # *, labels=None, weights=None, sample_weight=None)
print(kappa_lock_ann96_1)
kappa_lock_ann96_2 = cohen_kappa_score(l_ann_96, l_ann_93)
print(kappa_lock_ann96_2)
kappa_lock_ann96_3 = cohen_kappa_score(l_ann_96, l_ann_94)
print(kappa_lock_ann96_3)
kappa_lock_ann96_4 = cohen_kappa_score(l_ann_96, l_ann_95)
print(kappa_lock_ann96_4)
# Out:
# 0.07163323782234965
# 0.4598199399799934
# 0.48709002093510123
# 0.4885703215807826

# %%
#lock_kappa_score_ann96 =  (kappa_lock_ann96_1 + kappa_lock_ann96_2 + kappa_lock_ann96_3 + kappa_lock_ann96_4)/4
#print(lock_kappa_score_ann96)
#Calculate cohen's kappa score for annotator_96, annotator_53, annotator_93, annotator_94, annotator_95, from lockdown0 change.org file
lock0_kappa_score_ann96 =  (cohen_kappa_score(l_ann_96, l_ann_53) + cohen_kappa_score(l_ann_96, l_ann_95) + cohen_kappa_score(l_ann_96, l_ann_93) + cohen_kappa_score(l_ann_96, l_ann_94))/4
print(lock0_kappa_score_ann96)
lock0_kappa_score_ann53 =  (cohen_kappa_score(l_ann_53, l_ann_96) + cohen_kappa_score(l_ann_53, l_ann_93) + cohen_kappa_score(l_ann_53, l_ann_94) + cohen_kappa_score(l_ann_53, l_ann_95))/4
print(lock0_kappa_score_ann53)
lock0_kappa_score_ann93 =  (cohen_kappa_score(l_ann_93, l_ann_96) + cohen_kappa_score(l_ann_93, l_ann_53) + cohen_kappa_score(l_ann_93, l_ann_94) + cohen_kappa_score(l_ann_93, l_ann_95))/4
print(lock0_kappa_score_ann93)
lock0_kappa_score_ann94 =  (cohen_kappa_score(l_ann_94, l_ann_96) + cohen_kappa_score(l_ann_94, l_ann_53) + cohen_kappa_score(l_ann_94, l_ann_93) + cohen_kappa_score(l_ann_94, l_ann_95))/4
print(lock0_kappa_score_ann94)
lock0_kappa_score_ann95 =  (cohen_kappa_score(l_ann_95, l_ann_96) + cohen_kappa_score(l_ann_95, l_ann_53) + cohen_kappa_score(l_ann_95, l_ann_93) + cohen_kappa_score(l_ann_95, l_ann_94))/4
print(lock0_kappa_score_ann95)
# Out:
# 0.3767783800795567
# 0.03769865669786676
# 0.3456977184019719
# 0.4282583348403162
# 0.4248114868097386

# %%
df_l1.describe()
print(df_l1)
# Out:
#                                                   text  annotation_112  \
# 0    Get CoVID Vaccines to Nepal ASAP and prevent a...           False
# 1                         Compensate Essential Workers           False
# 2    Amend Recent COVID-19 Restrictions for Persona...           False
# 3    Petition against COVID-19 & Quarantine Bill: S...            True
# 4    KCL Has Coronavirus Case: Petition to Have Onl...            True
# 5                                       School safety.            True
# 6                     NCAA Covid-19 Eligibility Relief           False
# 7    RI State schools to STOP charging campus fees ...           False
# 8                   Let these military pets come home!           False
# 9           Texas State: Cancel all online class fees.           False
# 10   Vermeiden von Pandemien - Schließung chinesisc...           False
# 11   Help SJSU Students Cancel Their Lease at The G...           False
# ...

# %%
#storing annotators data in different variables
l_ann_112 = df_l1["annotation_112"]
l_ann_109 = df_l1["annotation_109"]
l_ann_110 = df_l1["annotation_110"]
l_ann_111 = df_l1["annotation_111"]

# %%
#Calculate cohen's kappa score for annotator_112, annotator_109, annotator_110, annotator_111, from lockdown1 change.org file
lock1_kappa_score_ann112 =  (cohen_kappa_score(l_ann_112, l_ann_109) + cohen_kappa_score(l_ann_112, l_ann_110) + cohen_kappa_score(l_ann_112, l_ann_111))/3
print(lock1_kappa_score_ann112)
lock1_kappa_score_ann109 =  (cohen_kappa_score(l_ann_109, l_ann_112) + cohen_kappa_score(l_ann_109, l_ann_110) + cohen_kappa_score(l_ann_109, l_ann_111))/3
print(lock1_kappa_score_ann109)
lock1_kappa_score_ann110 =  (cohen_kappa_score(l_ann_110, l_ann_112) + cohen_kappa_score(l_ann_110, l_ann_109) + cohen_kappa_score(l_ann_110, l_ann_111))/3
print(lock1_kappa_score_ann110)
lock1_kappa_score_ann111 =  (cohen_kappa_score(l_ann_111, l_ann_112) + cohen_kappa_score(l_ann_111, l_ann_109) + cohen_kappa_score(l_ann_111, l_ann_110))/3
print(lock1_kappa_score_ann111)
# Out:
# 0.39364100293054943
# 0.46609505372517274
# 0.35665361565697995
# 0.30649557663999455

# %%
df_l2.describe()
# Out:
#                                                      text annotation_73  \
# count                                                 300           300
# unique                                                300             2
# top     Hold the Chinese government accountable for CO...         False
# freq                                                    1           225
#
#        annotation_74 annotation_75 annotation_76
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             234           265           228

# %%
#storing annotators data in different variables
l_ann_73 = df_l2["annotation_73"]
l_ann_74 = df_l2["annotation_74"]
l_ann_75 = df_l2["annotation_75"]
l_ann_76 = df_l2["annotation_76"]

# %%
#Calculate cohen's kappa score for annotator_73, annotator_74, annotator_75, annotator_76, from lockdown1 change.org file
lock2_kappa_score_ann73 =  (cohen_kappa_score(l_ann_73, l_ann_74) + cohen_kappa_score(l_ann_73, l_ann_75) + cohen_kappa_score(l_ann_73, l_ann_76))/3
print(lock2_kappa_score_ann73)
lock2_kappa_score_ann74 =  (cohen_kappa_score(l_ann_74, l_ann_73) + cohen_kappa_score(l_ann_74, l_ann_75) + cohen_kappa_score(l_ann_74, l_ann_76))/3
print(lock2_kappa_score_ann74)
lock2_kappa_score_ann75 =  (cohen_kappa_score(l_ann_75, l_ann_73) + cohen_kappa_score(l_ann_75, l_ann_74) + cohen_kappa_score(l_ann_75, l_ann_76))/3
print(lock2_kappa_score_ann75)
lock2_kappa_score_ann76 =  (cohen_kappa_score(l_ann_76, l_ann_73) + cohen_kappa_score(l_ann_76, l_ann_74) + cohen_kappa_score(l_ann_76, l_ann_75))/3
print(lock2_kappa_score_ann76)
# Out:
# 0.622806139472806
# 0.6427222846004447
# 0.47905378802347115
# 0.6476747126970107

# %%
df_l3.describe()
# Out:
#                 text annotation_48 annotation_49 annotation_50 annotation_47
# count            300           300           300           300           300
# unique           300             2             2             2             2
# top     Save Schmidt         False         False         False         False
# freq               1           166           245           235           166

# %%
#storing annotators data in different variables
l_ann_48 = df_l3["annotation_48"]
l_ann_49 = df_l3["annotation_49"]
l_ann_50 = df_l3["annotation_50"]
l_ann_47 = df_l3["annotation_47"]

# %%
#Calculate cohen's kappa score for annotator_48, annotator_49, annotator_50, annotator_47, from lockdown1 change.org file
lock3_kappa_score_ann48 =  (cohen_kappa_score(l_ann_48, l_ann_49) + cohen_kappa_score(l_ann_48, l_ann_50) + cohen_kappa_score(l_ann_48, l_ann_47))/3
print(lock3_kappa_score_ann48)
lock3_kappa_score_ann49 =  (cohen_kappa_score(l_ann_49, l_ann_48) + cohen_kappa_score(l_ann_49, l_ann_50) + cohen_kappa_score(l_ann_49, l_ann_47))/3
print(lock3_kappa_score_ann49)
lock3_kappa_score_ann50 =  (cohen_kappa_score(l_ann_50, l_ann_48) + cohen_kappa_score(l_ann_50, l_ann_49) + cohen_kappa_score(l_ann_50, l_ann_47))/3
print(lock3_kappa_score_ann50)
lock3_kappa_score_ann47 =  (cohen_kappa_score(l_ann_47, l_ann_48) + cohen_kappa_score(l_ann_47, l_ann_49) + cohen_kappa_score(l_ann_47, l_ann_50))/3
print(lock3_kappa_score_ann47)
# Out:
# 0.4200460114235917
# 0.4371382830557451
# 0.45454008844232313
# 0.43423711832993034

# %%
df_l4.describe()
# Out:
#                                         text annotation_43 annotation_44  \
# count                                    300           300           300
# unique                                   300             2             2
# top     Stop Increasing Rent During COVID-19          True         False
# freq                                       1           245           250
#
#        annotation_45 annotation_46
# count            300           300
# unique             2             2
# top            False         False
# freq             201           226

# %%
#storing annotators data in different variables
l_ann_43 = df_l4["annotation_43"]
l_ann_44 = df_l4["annotation_44"]
l_ann_45 = df_l4["annotation_45"]
l_ann_46 = df_l4["annotation_46"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown1 change.org file
lock4_kappa_score_ann43 =  (cohen_kappa_score(l_ann_43, l_ann_44) + cohen_kappa_score(l_ann_43, l_ann_45) + cohen_kappa_score(l_ann_43, l_ann_46))/3
print(lock4_kappa_score_ann43)
lock4_kappa_score_ann44 =  (cohen_kappa_score(l_ann_44, l_ann_43) + cohen_kappa_score(l_ann_44, l_ann_45) + cohen_kappa_score(l_ann_44, l_ann_46))/3
print(lock4_kappa_score_ann44)
lock4_kappa_score_ann45 =  (cohen_kappa_score(l_ann_45, l_ann_43) + cohen_kappa_score(l_ann_45, l_ann_44) + cohen_kappa_score(l_ann_45, l_ann_46))/3
print(lock4_kappa_score_ann45)
lock4_kappa_score_ann46 =  (cohen_kappa_score(l_ann_46, l_ann_43) + cohen_kappa_score(l_ann_46, l_ann_44) + cohen_kappa_score(l_ann_46, l_ann_45))/3
print(lock4_kappa_score_ann46)
# Out:
# 0.09472345790245129
# 0.36010628808917683
# 0.38002727513320894
# 0.38613193821237113

# %%
df_m0.describe()
# Out:
#                                                      text annotation_96  \
# count                                                 300           300
# unique                                                300             2
# top     Yarra Valley should be classified as rural for...         False
# freq                                                    1           292
#
#        annotation_53 annotation_93 annotation_94 annotation_95
# count            300           300           300           300
# unique             2             2             2             2
# top            False         False         False         False
# freq             299           244           275           292

# %%
#Calculate cohen's kappa score for each annotator from each lockdown change.org files
#storing annotators data in different variables
m_ann_96 = df_m0["annotation_96"]
m_ann_53 = df_m0["annotation_53"]
m_ann_93 = df_m0["annotation_93"]
m_ann_94 = df_m0["annotation_94"]
m_ann_95 = df_m0["annotation_95"]

# %%
#Calculate cohen's kappa score for annotator_96, annotator_53, annotator_93, annotator_94, annotator_95, from lockdown0 change.org file
mask0_kappa_score_ann96 =  (cohen_kappa_score(m_ann_96, m_ann_53) + cohen_kappa_score(m_ann_96, m_ann_95) + cohen_kappa_score(m_ann_96, m_ann_93) + cohen_kappa_score(m_ann_96, m_ann_94))/4
print(mask0_kappa_score_ann96)
mask0_kappa_score_ann53 =  (cohen_kappa_score(m_ann_53, m_ann_96) + cohen_kappa_score(m_ann_53, m_ann_93) + cohen_kappa_score(m_ann_53, m_ann_94) + cohen_kappa_score(m_ann_53, m_ann_95))/4
print(mask0_kappa_score_ann53)
mask0_kappa_score_ann93 =  (cohen_kappa_score(m_ann_93, m_ann_96) + cohen_kappa_score(m_ann_93, m_ann_53) + cohen_kappa_score(m_ann_93, m_ann_94) + cohen_kappa_score(m_ann_93, m_ann_95))/4
print(mask0_kappa_score_ann93)
mask0_kappa_score_ann94 =  (cohen_kappa_score(m_ann_94, m_ann_96) + cohen_kappa_score(m_ann_94, m_ann_53) + cohen_kappa_score(m_ann_94, m_ann_93) + cohen_kappa_score(m_ann_94, m_ann_95))/4
print(mask0_kappa_score_ann94)
mask0_kappa_score_ann95 =  (cohen_kappa_score(m_ann_95, m_ann_96) + cohen_kappa_score(m_ann_95, m_ann_53) + cohen_kappa_score(m_ann_95, m_ann_93) + cohen_kappa_score(m_ann_95, m_ann_94))/4
print(mask0_kappa_score_ann95)
# Out:
# 0.2014534965592872
# -0.0062417514317987255
# 0.13854987904274066
# 0.1933687369210724
# 0.2576172341374985

# %%
df_m1.describe()
# Out:
#                                                    text annotation_112  \
# count                                               300            300
# unique                                              300              2
# top     Save Altitude Trampoline Park in Spokane Valley          False
# freq                                                  1            273
#
#        annotation_109 annotation_110 annotation_111
# count             300            300            300
# unique              2              2              2
# top             False          False          False
# freq              290            266            229

# %%
#storing annotators data in different variables
m_ann_112 = df_m1["annotation_112"]
m_ann_109 = df_m1["annotation_109"]
m_ann_110 = df_m1["annotation_110"]
m_ann_111 = df_m1["annotation_111"]

#Calculate cohen's kappa score for annotator_112, annotator_109, annotator_110, annotator_111, from lockdown1 change.org file
mask1_kappa_score_ann112 =  (cohen_kappa_score(m_ann_112, m_ann_109) + cohen_kappa_score(m_ann_112, m_ann_110) + cohen_kappa_score(m_ann_112, m_ann_111))/3
print(mask1_kappa_score_ann112)
mask1_kappa_score_ann109 =  (cohen_kappa_score(m_ann_109, m_ann_112) + cohen_kappa_score(m_ann_109, m_ann_110) + cohen_kappa_score(m_ann_109, m_ann_111))/3
print(mask1_kappa_score_ann109)
mask1_kappa_score_ann110 =  (cohen_kappa_score(m_ann_110, m_ann_112) + cohen_kappa_score(m_ann_110, m_ann_109) + cohen_kappa_score(m_ann_110, m_ann_111))/3
print(mask1_kappa_score_ann110)
mask1_kappa_score_ann111 =  (cohen_kappa_score(m_ann_111, m_ann_112) + cohen_kappa_score(m_ann_111, m_ann_109) + cohen_kappa_score(m_ann_111, m_ann_110))/3
print(mask1_kappa_score_ann111)
# Out:
# 0.3271023526433893
# 0.24974818844627159
# 0.2965985925198738
# 0.21345848907986684

# %%
df_m2.describe()
# Out:
#                                                      text annotation_73  \
# count                                                 300           300
# unique                                                300             2
# top     Hold the Chinese government accountable for CO...         False
# freq                                                    1           296
#
#        annotation_74 annotation_75 annotation_76
# count            300           300           300
# unique             2             1             2
# top            False         False         False
# freq             287           300           290

# %%
#storing annotators data in different variables
m_ann_73 = df_m2["annotation_73"]
m_ann_74 = df_m2["annotation_74"]
m_ann_75 = df_m2["annotation_75"]
m_ann_76 = df_m2["annotation_76"]

# %%
#Calculate cohen's kappa score for annotator_73, annotator_74, annotator_75, annotator_76, from masking change.org file
mask2_kappa_score_ann73 =  (cohen_kappa_score(m_ann_73, m_ann_74) + cohen_kappa_score(m_ann_73, m_ann_75) + cohen_kappa_score(m_ann_73, m_ann_76))/3
print(mask2_kappa_score_ann73)
mask2_kappa_score_ann74 =  (cohen_kappa_score(m_ann_74, m_ann_73) + cohen_kappa_score(m_ann_74, m_ann_75) + cohen_kappa_score(m_ann_74, m_ann_76))/3
print(mask2_kappa_score_ann74)
mask2_kappa_score_ann75 =  (cohen_kappa_score(m_ann_75, m_ann_73) + cohen_kappa_score(m_ann_75, m_ann_74) + cohen_kappa_score(m_ann_75, m_ann_76))/3
print(mask2_kappa_score_ann75)
mask2_kappa_score_ann76 =  (cohen_kappa_score(m_ann_76, m_ann_73) + cohen_kappa_score(m_ann_76, m_ann_74) + cohen_kappa_score(m_ann_76, m_ann_75))/3
print(mask2_kappa_score_ann76)

#print(m_ann_75)
#print(cohen_kappa_score(m_ann_75, m_ann_73))
#print(cohen_kappa_score(m_ann_75, m_ann_74))
#print(cohen_kappa_score(m_ann_74, m_ann_75))
#print(cohen_kappa_score(m_ann_75, m_ann_76))
# Out:
# 0.20377207915199477
# 0.22058691129610516
# 0.0
# 0.19804460560689363

# %%
df_m3.describe()
# Out:
#                 text annotation_48 annotation_49 annotation_50 annotation_47
# count            300           300           300           300           300
# unique           300             2             2             2             2
# top     Save Schmidt         False         False         False         False
# freq               1           273           289           292           271

# %%
#storing annotators data in different variables
m_ann_48 = df_m3["annotation_48"]
m_ann_49 = df_m3["annotation_49"]
m_ann_50 = df_m3["annotation_50"]
m_ann_47 = df_m3["annotation_47"]

# %%
#Calculate cohen's kappa score for annotator_48, annotator_49, annotator_50, annotator_47, from lockdown1 change.org file
mask3_kappa_score_ann48 =  (cohen_kappa_score(m_ann_48, m_ann_49) + cohen_kappa_score(m_ann_48, m_ann_50) + cohen_kappa_score(m_ann_48, m_ann_47))/3
print(mask3_kappa_score_ann48)
mask3_kappa_score_ann49 =  (cohen_kappa_score(m_ann_49, m_ann_48) + cohen_kappa_score(m_ann_49, m_ann_50) + cohen_kappa_score(m_ann_49, m_ann_47))/3
print(mask3_kappa_score_ann49)
mask3_kappa_score_ann50 =  (cohen_kappa_score(m_ann_50, m_ann_48) + cohen_kappa_score(m_ann_50, m_ann_49) + cohen_kappa_score(m_ann_50, m_ann_47))/3
print(mask3_kappa_score_ann50)
mask3_kappa_score_ann47 =  (cohen_kappa_score(m_ann_47, m_ann_48) + cohen_kappa_score(m_ann_47, m_ann_49) + cohen_kappa_score(m_ann_47, m_ann_50))/3
print(mask3_kappa_score_ann47)
# Out:
# 0.3646427764050817
# 0.49366428625005804
# 0.4672559392890074
# 0.4033470237744203

# %%
df_m4.describe()
# Out:
#                                         text annotation_43 annotation_44  \
# count                                    300           300           300
# unique                                   300             2             2
# top     Stop Increasing Rent During COVID-19         False         False
# freq                                       1           250           271
#
#        annotation_45 annotation_46
# count            300           300
# unique             2             2
# top            False         False
# freq             278           288

# %%
#storing annotators data in different variables
m_ann_43 = df_m4["annotation_43"]
m_ann_44 = df_m4["annotation_44"]
m_ann_45 = df_m4["annotation_45"]
m_ann_46 = df_m4["annotation_46"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from maskdown change.org file
mask4_kappa_score_ann43 =  (cohen_kappa_score(m_ann_43, m_ann_44) + cohen_kappa_score(m_ann_43, m_ann_45) + cohen_kappa_score(m_ann_43, m_ann_46))/3
print(mask4_kappa_score_ann43)
mask4_kappa_score_ann44 =  (cohen_kappa_score(m_ann_44, m_ann_43) + cohen_kappa_score(m_ann_44, m_ann_45) + cohen_kappa_score(m_ann_44, m_ann_46))/3
print(mask4_kappa_score_ann44)
mask4_kappa_score_ann45 =  (cohen_kappa_score(m_ann_45, m_ann_43) + cohen_kappa_score(m_ann_45, m_ann_44) + cohen_kappa_score(m_ann_45, m_ann_46))/3
print(mask4_kappa_score_ann45)
mask4_kappa_score_ann46 =  (cohen_kappa_score(m_ann_46, m_ann_43) + cohen_kappa_score(m_ann_46, m_ann_44) + cohen_kappa_score(m_ann_46, m_ann_45))/3
print(mask4_kappa_score_ann46)
# Out:
# 0.2050467381297456
# 0.3750365569505501
# 0.4517290066893758
# 0.38693576068206964

# %%
df_v0.describe()
# Out:
#                                                      text annotation_96  \
# count                                                 300           300
# unique                                                300             2
# top     Yarra Valley should be classified as rural for...         False
# freq                                                    1           293
#
#        annotation_53 annotation_93 annotation_94 annotation_95
# count            300           300           300           300
# unique             2             2             2             2
# top            False         False         False         False
# freq             299           295           297           297

# %%
#Calculate cohen's kappa score for each annotator from each vaccination change.org files
#storing annotators data in different variables
v_ann_96 = df_v0["annotation_96"]
v_ann_53 = df_v0["annotation_53"]
v_ann_93 = df_v0["annotation_93"]
v_ann_94 = df_v0["annotation_94"]
v_ann_95 = df_v0["annotation_95"]

# %%
#Calculate cohen's kappa score for annotator_96, annotator_53, annotator_93, annotator_94, annotator_95, from vaccination change.org file
vacc0_kappa_score_ann96 =  (cohen_kappa_score(v_ann_96, v_ann_53) + cohen_kappa_score(v_ann_96, v_ann_95) + cohen_kappa_score(v_ann_96, v_ann_93) + cohen_kappa_score(v_ann_96, v_ann_94))/4
print(vacc0_kappa_score_ann96)
vacc0_kappa_score_ann53 =  (cohen_kappa_score(v_ann_53, v_ann_96) + cohen_kappa_score(v_ann_53, v_ann_93) + cohen_kappa_score(v_ann_53, v_ann_94) + cohen_kappa_score(v_ann_53, v_ann_95))/4
print(vacc0_kappa_score_ann53)
vacc0_kappa_score_ann93 =  (cohen_kappa_score(v_ann_93, v_ann_96) + cohen_kappa_score(v_ann_93, v_ann_53) + cohen_kappa_score(v_ann_93, v_ann_94) + cohen_kappa_score(v_ann_93, v_ann_95))/4
print(vacc0_kappa_score_ann93)
vacc0_kappa_score_ann94 =  (cohen_kappa_score(v_ann_94, v_ann_96) + cohen_kappa_score(v_ann_94, v_ann_53) + cohen_kappa_score(v_ann_94, v_ann_93) + cohen_kappa_score(v_ann_94, v_ann_95))/4
print(vacc0_kappa_score_ann94)
vacc0_kappa_score_ann95 =  (cohen_kappa_score(v_ann_95, v_ann_96) + cohen_kappa_score(v_ann_95, v_ann_53) + cohen_kappa_score(v_ann_95, v_ann_93) + cohen_kappa_score(v_ann_95, v_ann_94))/4
print(vacc0_kappa_score_ann95)
# Out:
# 0.12217198608644952
# -0.005376101051554338
# 0.2621759843646737
# 0.2509715151694918
# 0.13697043678091242

# %%
df_v1.describe()
# Out:
#                                                    text annotation_112  \
# count                                               300            300
# unique                                              300              2
# top     Save Altitude Trampoline Park in Spokane Valley          False
# freq                                                  1            293
#
#        annotation_109 annotation_110 annotation_111
# count             300            300            300
# unique              2              2              2
# top             False          False          False
# freq              290            271            245

# %%
#storing annotators data in different variables
v_ann_112 = df_v1["annotation_112"]
v_ann_109 = df_v1["annotation_109"]
v_ann_110 = df_v1["annotation_110"]
v_ann_111 = df_v1["annotation_111"]

#Calculate cohen's kappa score for annotator_112, annotator_109, annotator_110, annotator_111, from lockdown1 change.org file
vacc1_kappa_score_ann112 =  (cohen_kappa_score(v_ann_112, v_ann_109) + cohen_kappa_score(v_ann_112, v_ann_110) + cohen_kappa_score(v_ann_112, v_ann_111))/3
print(vacc1_kappa_score_ann112)
vacc1_kappa_score_ann109 =  (cohen_kappa_score(v_ann_109, v_ann_112) + cohen_kappa_score(v_ann_109, v_ann_110) + cohen_kappa_score(v_ann_109, v_ann_111))/3
print(vacc1_kappa_score_ann109)
vacc1_kappa_score_ann110 =  (cohen_kappa_score(v_ann_110, v_ann_112) + cohen_kappa_score(v_ann_110, v_ann_109) + cohen_kappa_score(v_ann_110, v_ann_111))/3
print(vacc1_kappa_score_ann110)
vacc1_kappa_score_ann111 =  (cohen_kappa_score(v_ann_111, v_ann_112) + cohen_kappa_score(v_ann_111, v_ann_109) + cohen_kappa_score(v_ann_111, v_ann_110))/3
print(vacc1_kappa_score_ann111)
# Out:
# 0.4071067270825585
# 0.41143158404552654
# 0.33597392235776047
# 0.15714412525374102

# %%
df_v2.describe()
# Out:
#                                                      text annotation_73  \
# count                                                 300           300
# unique                                                300             2
# top     Hold the Chinese government accountable for CO...         False
# freq                                                    1           294
#
#        annotation_74 annotation_75 annotation_76
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             295           297           296

# %%
#storing annotators data in different variables
v_ann_73 = df_v2["annotation_73"]
v_ann_74 = df_v2["annotation_74"]
v_ann_75 = df_v2["annotation_75"]
v_ann_76 = df_v2["annotation_76"]

# %%
#Calculate cohen's kappa score for annotator_73, annotator_74, annotator_75, annotator_76, from masking change.org file
vacc2_kappa_score_ann73 =  (cohen_kappa_score(v_ann_73, v_ann_74) + cohen_kappa_score(v_ann_73, v_ann_75) + cohen_kappa_score(v_ann_73, v_ann_76))/3
print(vacc2_kappa_score_ann73)
vacc2_kappa_score_ann74 =  (cohen_kappa_score(v_ann_74, v_ann_73) + cohen_kappa_score(v_ann_74, v_ann_75) + cohen_kappa_score(v_ann_74, v_ann_76))/3
print(vacc2_kappa_score_ann74)
vacc2_kappa_score_ann75 =  (cohen_kappa_score(v_ann_75, v_ann_73) + cohen_kappa_score(v_ann_75, v_ann_74) + cohen_kappa_score(v_ann_75, v_ann_76))/3
print(vacc2_kappa_score_ann75)
vacc2_kappa_score_ann76 =  (cohen_kappa_score(v_ann_76, v_ann_73) + cohen_kappa_score(v_ann_76, v_ann_74) + cohen_kappa_score(v_ann_76, v_ann_75))/3
print(vacc2_kappa_score_ann76)

#print(m_ann_75)
#print(cohen_kappa_score(m_ann_75, m_ann_73))
#print(cohen_kappa_score(m_ann_75, m_ann_74))
#print(cohen_kappa_score(m_ann_74, m_ann_75))
#print(cohen_kappa_score(m_ann_75, m_ann_76))
# Out:
# 0.6519690422129448
# 0.7854252367909931
# 0.5834154561380728
# 0.7501466670105877

# %%
df_v3.describe()
# Out:
#                 text annotation_48 annotation_49 annotation_50 annotation_47
# count            300           300           300           300           300
# unique           300             2             2             2             2
# top     Save Schmidt         False         False         False         False
# freq               1           292           297           298           294

# %%
#storing annotators data in different variables
v_ann_48 = df_v3["annotation_48"]
v_ann_49 = df_v3["annotation_49"]
v_ann_50 = df_v3["annotation_50"]
v_ann_47 = df_v3["annotation_47"]

# %%
#Calculate cohen's kappa score for annotator_48, annotator_49, annotator_50, annotator_47, from lockdown1 change.org file
vacc3_kappa_score_ann48 =  (cohen_kappa_score(v_ann_48, v_ann_49) + cohen_kappa_score(v_ann_48, v_ann_50) + cohen_kappa_score(v_ann_48, v_ann_47))/3
print(vacc3_kappa_score_ann48)
vacc3_kappa_score_ann49 =  (cohen_kappa_score(v_ann_49, v_ann_48) + cohen_kappa_score(v_ann_49, v_ann_50) + cohen_kappa_score(v_ann_49, v_ann_47))/3
print(vacc3_kappa_score_ann49)
vacc3_kappa_score_ann50 =  (cohen_kappa_score(v_ann_50, v_ann_48) + cohen_kappa_score(v_ann_50, v_ann_49) + cohen_kappa_score(v_ann_50, v_ann_47))/3
print(vacc3_kappa_score_ann50)
vacc3_kappa_score_ann47 =  (cohen_kappa_score(v_ann_47, v_ann_48) + cohen_kappa_score(v_ann_47, v_ann_49) + cohen_kappa_score(v_ann_47, v_ann_50))/3
print(vacc3_kappa_score_ann47)
# Out:
# 0.3876597393675265
# 0.6049309337905934
# 0.5622891963427569
# 0.5241054451580767

# %%
df_v4.describe()
# Out:
#                                         text annotation_43 annotation_44  \
# count                                    300           300           300
# unique                                   300             2             2
# top     Stop Increasing Rent During COVID-19         False         False
# freq                                       1           294           296
#
#        annotation_45 annotation_46
# count            300           300
# unique             2             2
# top            False         False
# freq             295           293

# %%
#storing annotators data in different variables
v_ann_43 = df_v4["annotation_43"]
v_ann_44 = df_v4["annotation_44"]
v_ann_45 = df_v4["annotation_45"]
v_ann_46 = df_v4["annotation_46"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from vaccination change.org file
vacc4_kappa_score_ann43 =  (cohen_kappa_score(v_ann_43, v_ann_44) + cohen_kappa_score(v_ann_43, v_ann_45) + cohen_kappa_score(v_ann_43, v_ann_46))/3
print(vacc4_kappa_score_ann43)
vacc4_kappa_score_ann44 =  (cohen_kappa_score(v_ann_44, v_ann_43) + cohen_kappa_score(v_ann_44, v_ann_45) + cohen_kappa_score(v_ann_44, v_ann_46))/3
print(vacc4_kappa_score_ann44)
vacc4_kappa_score_ann45 =  (cohen_kappa_score(v_ann_45, v_ann_43) + cohen_kappa_score(v_ann_45, v_ann_44) + cohen_kappa_score(v_ann_45, v_ann_46))/3
print(vacc4_kappa_score_ann45)
vacc4_kappa_score_ann46 =  (cohen_kappa_score(v_ann_46, v_ann_43) + cohen_kappa_score(v_ann_46, v_ann_44) + cohen_kappa_score(v_ann_46, v_ann_45))/3
print(vacc4_kappa_score_ann46)
# Out:
# 0.5267395021958605
# 0.7344262383224409
# 0.751427803587239
# 0.6674261993660947

# %%
#Twitter data
##Calculate cohen's kappa score for each annotator from each lockdown twitter files

# %%
tw_df_l0.describe()
# Out:
#                                                      text annotation_104  \
# count                                                 300            300
# unique                                                300              2
# top     I don’t think now is a good time to get arrest...          False
# freq                                                    1            262
#
#        annotation_101 annotation_102 annotation_103
# count             300            300            300
# unique              2              2              2
# top             False          False          False
# freq              286            297            297

# %%
#storing annotators data in different variables
l_ann_104 = tw_df_l0["annotation_104"]
l_ann_101 = tw_df_l0["annotation_101"]
l_ann_102 = tw_df_l0["annotation_102"]
l_ann_103 = tw_df_l0["annotation_103"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
lock0_kappa_score_ann104 =  (cohen_kappa_score(l_ann_104, l_ann_101) + cohen_kappa_score(l_ann_104, l_ann_102) + cohen_kappa_score(l_ann_104, l_ann_103))/3
print(lock0_kappa_score_ann104)
lock0_kappa_score_ann101 =  (cohen_kappa_score(l_ann_101, l_ann_104) + cohen_kappa_score(l_ann_101, l_ann_102) + cohen_kappa_score(l_ann_101, l_ann_103))/3
print(lock0_kappa_score_ann101)
lock0_kappa_score_ann102 =  (cohen_kappa_score(l_ann_102, l_ann_104) + cohen_kappa_score(l_ann_102, l_ann_101) + cohen_kappa_score(l_ann_102, l_ann_103))/3
print(lock0_kappa_score_ann102)
lock0_kappa_score_ann103 =  (cohen_kappa_score(l_ann_103, l_ann_104) + cohen_kappa_score(l_ann_103, l_ann_101) + cohen_kappa_score(l_ann_103, l_ann_102))/3
print(lock0_kappa_score_ann103)
# Out:
# 0.15310922941528948
# 0.20788424756793666
# 0.1699956795349352
# 0.20986808782839614

# %%
tw_df_m0.describe()
# Out:
#                                                      text annotation_104  \
# count                                                 300            300
# unique                                                300              2
# top     I don’t think now is a good time to get arrest...          False
# freq                                                    1            180
#
#        annotation_101 annotation_102 annotation_103
# count             300            300            300
# unique              2              2              2
# top             False          False          False
# freq              241            236            239

# %%
#storing annotators data in different variables
m_ann_104 = tw_df_m0["annotation_104"]
m_ann_101 = tw_df_m0["annotation_101"]
m_ann_102 = tw_df_m0["annotation_102"]
m_ann_103 = tw_df_m0["annotation_103"]

# %%
#Calculate cohen's kappa score from masking twitter file
mask0_kappa_score_ann104 =  (cohen_kappa_score(m_ann_104, m_ann_101) + cohen_kappa_score(m_ann_104, m_ann_102) + cohen_kappa_score(m_ann_104, m_ann_103))/3
print(mask0_kappa_score_ann104)
mask0_kappa_score_ann101 =  (cohen_kappa_score(m_ann_101, m_ann_104) + cohen_kappa_score(m_ann_101, m_ann_102) + cohen_kappa_score(m_ann_101, m_ann_103))/3
print(mask0_kappa_score_ann101)
mask0_kappa_score_ann102 =  (cohen_kappa_score(m_ann_102, m_ann_104) + cohen_kappa_score(m_ann_102, m_ann_101) + cohen_kappa_score(m_ann_102, m_ann_103))/3
print(mask0_kappa_score_ann102)
mask0_kappa_score_ann103 =  (cohen_kappa_score(m_ann_103, m_ann_104) + cohen_kappa_score(m_ann_103, m_ann_101) + cohen_kappa_score(m_ann_103, m_ann_102))/3
print(mask0_kappa_score_ann103)
# Out:
# 0.5110966318263074
# 0.7704815888817947
# 0.7327868362752801
# 0.7630634070755388

# %%
tw_df_v0.describe()
# Out:
#                                                      text annotation_104  \
# count                                                 300            300
# unique                                                300              2
# top     I don’t think now is a good time to get arrest...           True
# freq                                                    1            151
#
#        annotation_101 annotation_102 annotation_103
# count             300            300            300
# unique              2              2              2
# top              True           True          False
# freq              169            155            158

# %%
#storing annotators data in different variables
v_ann_104 = tw_df_v0["annotation_104"]
v_ann_101 = tw_df_v0["annotation_101"]
v_ann_102 = tw_df_v0["annotation_102"]
v_ann_103 = tw_df_v0["annotation_103"]

# %%
#Calculate cohen's kappa score from vaccination twitter file
vacc0_kappa_score_ann104 =  (cohen_kappa_score(v_ann_104, v_ann_101) + cohen_kappa_score(v_ann_104, v_ann_102) + cohen_kappa_score(v_ann_104, v_ann_103))/3
print(vacc0_kappa_score_ann104)
vacc0_kappa_score_ann101 =  (cohen_kappa_score(v_ann_101, v_ann_104) + cohen_kappa_score(v_ann_101, v_ann_102) + cohen_kappa_score(v_ann_101, v_ann_103))/3
print(vacc0_kappa_score_ann101)
vacc0_kappa_score_ann102 =  (cohen_kappa_score(v_ann_102, v_ann_104) + cohen_kappa_score(v_ann_102, v_ann_101) + cohen_kappa_score(v_ann_102, v_ann_103))/3
print(vacc0_kappa_score_ann102)
vacc0_kappa_score_ann103 =  (cohen_kappa_score(v_ann_103, v_ann_104) + cohen_kappa_score(v_ann_103, v_ann_101) + cohen_kappa_score(v_ann_103, v_ann_102))/3
print(vacc0_kappa_score_ann103)
# Out:
# 0.673287439979103
# 0.7621309462828351
# 0.6241408556645266
# 0.7095627314652487

# %%
tw_df_l1.describe()
# Out:
#                                                      text annotation_51  \
# count                                                 300           300
# unique                                                300             2
# top     This #Individualism shit might make it so we n...         False
# freq                                                    1           270
#
#        annotation_52 annotation_53 annotation_54
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             281           279           278

# %%
#storing annotators data in different variables
l_ann_51 = tw_df_l1["annotation_51"]
l_ann_52 = tw_df_l1["annotation_52"]
l_ann_53 = tw_df_l1["annotation_53"]
l_ann_54 = tw_df_l1["annotation_54"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
lock1_kappa_score_ann51 =  (cohen_kappa_score(l_ann_51, l_ann_52) + cohen_kappa_score(l_ann_51, l_ann_53) + cohen_kappa_score(l_ann_51, l_ann_54))/3
print(lock1_kappa_score_ann51)
lock1_kappa_score_ann52 =  (cohen_kappa_score(l_ann_52, l_ann_51) + cohen_kappa_score(l_ann_52, l_ann_53) + cohen_kappa_score(l_ann_52, l_ann_54))/3
print(lock1_kappa_score_ann52)
lock1_kappa_score_ann53 =  (cohen_kappa_score(l_ann_53, l_ann_51) + cohen_kappa_score(l_ann_53, l_ann_52) + cohen_kappa_score(l_ann_53, l_ann_54))/3
print(lock1_kappa_score_ann53)
lock1_kappa_score_ann54 =  (cohen_kappa_score(l_ann_54, l_ann_51) + cohen_kappa_score(l_ann_54, l_ann_52) + cohen_kappa_score(l_ann_54, l_ann_53))/3
print(lock1_kappa_score_ann54)
# Out:
# 0.38374396729420157
# 0.2475066127986606
# 0.3466783318742191
# 0.3615994589823533

# %%
tw_df_m1.describe()
# Out:
#                                                      text annotation_51  \
# count                                                 300           300
# unique                                                300             2
# top     This #Individualism shit might make it so we n...         False
# freq                                                    1           189
#
#        annotation_52 annotation_53 annotation_54
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             247           224           247

# %%
#storing annotators data in different variables
m_ann_51 = tw_df_m1["annotation_51"]
m_ann_52 = tw_df_m1["annotation_52"]
m_ann_53 = tw_df_m1["annotation_53"]
m_ann_54 = tw_df_m1["annotation_54"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
mask1_kappa_score_ann51 =  (cohen_kappa_score(m_ann_51, m_ann_52) + cohen_kappa_score(m_ann_51, m_ann_53) + cohen_kappa_score(m_ann_51, m_ann_54))/3
print(mask1_kappa_score_ann51)
mask1_kappa_score_ann52 =  (cohen_kappa_score(m_ann_52, m_ann_51) + cohen_kappa_score(m_ann_52, m_ann_53) + cohen_kappa_score(m_ann_52, m_ann_54))/3
print(mask1_kappa_score_ann52)
mask1_kappa_score_ann53 =  (cohen_kappa_score(m_ann_53, m_ann_51) + cohen_kappa_score(m_ann_53, m_ann_52) + cohen_kappa_score(m_ann_53, m_ann_54))/3
print(mask1_kappa_score_ann53)
mask1_kappa_score_ann54 =  (cohen_kappa_score(m_ann_54, m_ann_51) + cohen_kappa_score(m_ann_54, m_ann_52) + cohen_kappa_score(m_ann_54, m_ann_53))/3
print(mask1_kappa_score_ann54)
# Out:
# 0.5547693664516317
# 0.6992497233396247
# 0.6807204926375218
# 0.7045924598892853

# %%
tw_df_v1.describe()
# Out:
#                                                      text annotation_51  \
# count                                                 300           300
# unique                                                300             2
# top     This #Individualism shit might make it so we n...          True
# freq                                                    1           186
#
#        annotation_52 annotation_53 annotation_54
# count            300           300           300
# unique             2             2             2
# top            False          True          True
# freq             208           195           158

# %%
#storing annotators data in different variables
v_ann_51 = tw_df_v1["annotation_51"]
v_ann_52 = tw_df_v1["annotation_52"]
v_ann_53 = tw_df_v1["annotation_53"]
v_ann_54 = tw_df_v1["annotation_54"]

# %%
#Calculate cohen's kappa score from masking twitter file
vacc1_kappa_score_ann51 =  (cohen_kappa_score(v_ann_51, v_ann_52) + cohen_kappa_score(v_ann_51, v_ann_53) + cohen_kappa_score(v_ann_51, v_ann_54))/3
print(vacc1_kappa_score_ann51)
vacc1_kappa_score_ann52 =  (cohen_kappa_score(v_ann_52, v_ann_51) + cohen_kappa_score(v_ann_52, v_ann_53) + cohen_kappa_score(v_ann_52, v_ann_54))/3
print(vacc1_kappa_score_ann52)
vacc1_kappa_score_ann53 =  (cohen_kappa_score(v_ann_53, v_ann_51) + cohen_kappa_score(v_ann_53, v_ann_52) + cohen_kappa_score(v_ann_53, v_ann_54))/3
print(vacc1_kappa_score_ann53)
vacc1_kappa_score_ann54 =  (cohen_kappa_score(v_ann_54, v_ann_51) + cohen_kappa_score(v_ann_54, v_ann_52) + cohen_kappa_score(v_ann_54, v_ann_53))/3
print(vacc1_kappa_score_ann54)
# Out:
# 0.6557455942279518
# 0.3626159972414958
# 0.6134981271639437
# 0.6083138882680158

# %%
tw_df_l2.describe()
# Out:
#                                                      text annotation_56  \
# count                                                 300           300
# unique                                                300             2
# top     It will probably be compulsory here too. Why e...         False
# freq                                                    1           194
#
#        annotation_57 annotation_58 annotation_59
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             291           249           289

# %%
#storing annotators data in different variables
l_ann_56 = tw_df_l2["annotation_56"]
l_ann_57 = tw_df_l2["annotation_57"]
l_ann_58 = tw_df_l2["annotation_58"]
l_ann_59 = tw_df_l2["annotation_59"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
lock2_kappa_score_ann56 =  (cohen_kappa_score(l_ann_56, l_ann_57) + cohen_kappa_score(l_ann_56, l_ann_58) + cohen_kappa_score(l_ann_56, l_ann_59))/3
print(lock2_kappa_score_ann56)
lock2_kappa_score_ann57 =  (cohen_kappa_score(l_ann_57, l_ann_56) + cohen_kappa_score(l_ann_57, l_ann_58) + cohen_kappa_score(l_ann_57, l_ann_59))/3
print(lock2_kappa_score_ann57)
lock2_kappa_score_ann58 =  (cohen_kappa_score(l_ann_58, l_ann_56) + cohen_kappa_score(l_ann_58, l_ann_57) + cohen_kappa_score(l_ann_58, l_ann_59))/3
print(lock2_kappa_score_ann58)
lock2_kappa_score_ann59 =  (cohen_kappa_score(l_ann_59, l_ann_56) + cohen_kappa_score(l_ann_59, l_ann_57) + cohen_kappa_score(l_ann_59, l_ann_58))/3
print(lock2_kappa_score_ann59)
# Out:
# 0.1163835813527575
# 0.30077990922116665
# 0.19539052471284699
# 0.30290799595403145

# %%
tw_df_m2.describe()
# Out:
#                                                      text annotation_56  \
# count                                                 300           300
# unique                                                300             2
# top     It will probably be compulsory here too. Why e...         False
# freq                                                    1           245
#
#        annotation_57 annotation_58 annotation_59
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             193           187           234

# %%
#storing annotators data in different variables
m_ann_56 = tw_df_m2["annotation_56"]
m_ann_57 = tw_df_m2["annotation_57"]
m_ann_58 = tw_df_m2["annotation_58"]
m_ann_59 = tw_df_m2["annotation_59"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
mask2_kappa_score_ann56 =  (cohen_kappa_score(m_ann_56, m_ann_57) + cohen_kappa_score(m_ann_56, m_ann_58) + cohen_kappa_score(m_ann_56, m_ann_59))/3
print(mask2_kappa_score_ann56)
mask2_kappa_score_ann57 =  (cohen_kappa_score(m_ann_57, m_ann_56) + cohen_kappa_score(m_ann_57, m_ann_58) + cohen_kappa_score(m_ann_57, m_ann_59))/3
print(mask2_kappa_score_ann57)
mask2_kappa_score_ann58 =  (cohen_kappa_score(m_ann_58, m_ann_56) + cohen_kappa_score(m_ann_58, m_ann_57) + cohen_kappa_score(m_ann_58, m_ann_59))/3
print(mask2_kappa_score_ann58)
mask2_kappa_score_ann59 =  (cohen_kappa_score(m_ann_59, m_ann_56) + cohen_kappa_score(m_ann_59, m_ann_57) + cohen_kappa_score(m_ann_59, m_ann_58))/3
print(mask2_kappa_score_ann59)
# Out:
# 0.6346300788322754
# 0.6029432092245662
# 0.5641640469267309
# 0.6629464534041484

# %%
tw_df_v2.describe()
# Out:
#                                                      text annotation_56  \
# count                                                 300           300
# unique                                                300             2
# top     It will probably be compulsory here too. Why e...          True
# freq                                                    1           154
#
#        annotation_57 annotation_58 annotation_59
# count            300           300           300
# unique             2             2             2
# top             True          True          True
# freq             154           173           170

# %%
#storing annotators data in different variables
v_ann_56 = tw_df_v2["annotation_56"]
v_ann_57 = tw_df_v2["annotation_57"]
v_ann_58 = tw_df_v2["annotation_58"]
v_ann_59 = tw_df_v2["annotation_59"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
vacc2_kappa_score_ann56 =  (cohen_kappa_score(v_ann_56, v_ann_57) + cohen_kappa_score(v_ann_56, v_ann_58) + cohen_kappa_score(v_ann_56, v_ann_59))/3
print(vacc2_kappa_score_ann56)
vacc2_kappa_score_ann57 =  (cohen_kappa_score(v_ann_57, v_ann_56) + cohen_kappa_score(v_ann_57, v_ann_58) + cohen_kappa_score(v_ann_57, v_ann_59))/3
print(vacc2_kappa_score_ann57)
vacc2_kappa_score_ann58 =  (cohen_kappa_score(v_ann_58, v_ann_56) + cohen_kappa_score(v_ann_58, v_ann_57) + cohen_kappa_score(v_ann_58, v_ann_59))/3
print(vacc2_kappa_score_ann58)
vacc2_kappa_score_ann59 =  (cohen_kappa_score(v_ann_59, v_ann_56) + cohen_kappa_score(v_ann_59, v_ann_57) + cohen_kappa_score(v_ann_59, v_ann_58))/3
print(vacc2_kappa_score_ann59)
# Out:
# 0.6901550441139593
# 0.6946177360097107
# 0.5853754265879894
# 0.7371881632778615

# %%
tw_df_l3.describe()
# Out:
#                                                      text annotation_91  \
# count                                                 300           300
# unique                                                299             2
# top     STUDIES SHOW MORPHINE MILLIGRAM EQUIVALENT (MM...         False
# freq                                                    2           289
#
#        annotation_85 annotation_86 annotation_87
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             283           296           274

# %%
#storing annotators data in different variables
l_ann_91 = tw_df_l3["annotation_91"]
l_ann_85 = tw_df_l3["annotation_85"]
l_ann_86 = tw_df_l3["annotation_86"]
l_ann_87 = tw_df_l3["annotation_87"]

# %%
#Calculate cohen's kappa score from lockdown twitter file
lock3_kappa_score_ann91 =  (cohen_kappa_score(l_ann_91, l_ann_85) + cohen_kappa_score(l_ann_91, l_ann_86) + cohen_kappa_score(l_ann_91, l_ann_87))/3
print(lock3_kappa_score_ann91)
lock3_kappa_score_ann85 =  (cohen_kappa_score(l_ann_85, l_ann_91) + cohen_kappa_score(l_ann_85, l_ann_86) + cohen_kappa_score(l_ann_85, l_ann_87))/3
print(lock3_kappa_score_ann85)
lock3_kappa_score_ann86 =  (cohen_kappa_score(l_ann_86, l_ann_91) + cohen_kappa_score(l_ann_86, l_ann_85) + cohen_kappa_score(l_ann_86, l_ann_87))/3
print(lock3_kappa_score_ann86)
lock3_kappa_score_ann87 =  (cohen_kappa_score(l_ann_87, l_ann_91) + cohen_kappa_score(l_ann_87, l_ann_85) + cohen_kappa_score(l_ann_87, l_ann_86))/3
print(lock3_kappa_score_ann87)
# Out:
# 0.32835570175628914
# 0.21786806677463708
# 0.19204609283718876
# 0.2611111700445586

# %%
tw_df_m3.describe()
# Out:
#                                                      text annotation_91  \
# count                                                 300           300
# unique                                                299             2
# top     STUDIES SHOW MORPHINE MILLIGRAM EQUIVALENT (MM...         False
# freq                                                    2           231
#
#        annotation_85 annotation_86 annotation_87
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             246           235           228

# %%
#storing annotators data in different variables
m_ann_91 = tw_df_m3["annotation_91"]
m_ann_85 = tw_df_m3["annotation_85"]
m_ann_86 = tw_df_m3["annotation_86"]
m_ann_87 = tw_df_m3["annotation_87"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
mask3_kappa_score_ann91 =  (cohen_kappa_score(m_ann_91, m_ann_85) + cohen_kappa_score(m_ann_91, m_ann_86) + cohen_kappa_score(m_ann_91, m_ann_87))/3
print(mask3_kappa_score_ann91)
mask3_kappa_score_ann85 =  (cohen_kappa_score(m_ann_85, m_ann_91) + cohen_kappa_score(m_ann_85, m_ann_86) + cohen_kappa_score(m_ann_85, m_ann_87))/3
print(mask3_kappa_score_ann85)
mask3_kappa_score_ann86 =  (cohen_kappa_score(m_ann_86, m_ann_91) + cohen_kappa_score(m_ann_86, m_ann_85) + cohen_kappa_score(m_ann_86, m_ann_87))/3
print(mask3_kappa_score_ann86)
mask3_kappa_score_ann87 =  (cohen_kappa_score(m_ann_87, m_ann_91) + cohen_kappa_score(m_ann_87, m_ann_85) + cohen_kappa_score(m_ann_87, m_ann_86))/3
print(mask3_kappa_score_ann87)
# Out:
# 0.8319435933703723
# 0.8032421828800219
# 0.8556110752019936
# 0.8140977640978617

# %%
tw_df_v3.describe()
# Out:
#                                                      text annotation_91  \
# count                                                 300           300
# unique                                                299             2
# top     STUDIES SHOW MORPHINE MILLIGRAM EQUIVALENT (MM...          True
# freq                                                    2           176
#
#        annotation_85 annotation_86 annotation_87
# count            300           300           300
# unique             2             2             2
# top             True         False          True
# freq             174           167           177

# %%
#storing annotators data in different variables
v_ann_91 = tw_df_v3["annotation_91"]
v_ann_85 = tw_df_v3["annotation_85"]
v_ann_86 = tw_df_v3["annotation_86"]
v_ann_87 = tw_df_v3["annotation_87"]

# %%
#Calculate cohen's kappa score for annotator_43, annotator_44, annotator_45, annotator_46, from lockdown0 twitter file
vacc3_kappa_score_ann91 =  (cohen_kappa_score(v_ann_91, v_ann_85) + cohen_kappa_score(v_ann_91, v_ann_86) + cohen_kappa_score(v_ann_91, v_ann_87))/3
print(vacc3_kappa_score_ann91)
vacc3_kappa_score_ann85 =  (cohen_kappa_score(v_ann_85, v_ann_91) + cohen_kappa_score(v_ann_85, v_ann_86) + cohen_kappa_score(v_ann_85, v_ann_87))/3
print(vacc3_kappa_score_ann85)
vacc3_kappa_score_ann86 =  (cohen_kappa_score(v_ann_86, v_ann_91) + cohen_kappa_score(v_ann_86, v_ann_85) + cohen_kappa_score(v_ann_86, v_ann_87))/3
print(vacc3_kappa_score_ann86)
vacc3_kappa_score_ann87 =  (cohen_kappa_score(v_ann_87, v_ann_91) + cohen_kappa_score(v_ann_87, v_ann_85) + cohen_kappa_score(v_ann_87, v_ann_86))/3
print(vacc3_kappa_score_ann87)
# Out:
# 0.6676275621130413
# 0.657906452588274
# 0.6207114581266412
# 0.6359096142185358

# %%
#PART 2
change_org_l0 = pd.DataFrame(data=df_l0["text"], columns = ["text"])
change_org_l0.describe()
#print(change_org_l0)
#change_org_l0 = pd.read_csv("/home/akshay/Desktop/IIT courses/NLP/Project_Phase_2/change.org_topic_0_lockdowns.csv", names=['text'])
# Out:
#                                                      text
# count                                                 300
# unique                                                300
# top     Yarra Valley should be classified as rural for...
# freq                                                    1

# %%
#eliminate annotators which are not reliable 
#change.org lockdown file 0
#annotators 96, 53, 93, 94, 95
if lock0_kappa_score_ann96 < 0.2:
    print("lock0_kappa_score_ann96 not reliable")
    
if lock0_kappa_score_ann53 < 0.2:
    print("lock0_kappa_score_ann53 not reliable")
    
if lock0_kappa_score_ann93 < 0.2:
    print("lock0_kappa_score_ann93 not reliable")
    
if lock0_kappa_score_ann94 < 0.2:
    print("lock0_kappa_score_ann94 not reliable")
    
if lock0_kappa_score_ann95 < 0.2:
    print("lock0_kappa_score_ann95 not reliable")

#check high reliability annotator in case of tie

high_ann_l0 ={'ann96': lock0_kappa_score_ann96, 'ann93': lock0_kappa_score_ann93, 'ann94': lock0_kappa_score_ann94, 'ann95': lock0_kappa_score_ann95}
print(high_ann_l0)
#annotator with higher reliability
high_rel_ann_l0 = max(high_ann_l0, key=high_ann_l0.get)
print("High-reliability annotator is", high_rel_ann_l0)
# Out:
# lock0_kappa_score_ann53 not reliable
# {'ann96': 0.3767783800795567, 'ann93': 0.3456977184019719, 'ann94': 0.4282583348403162, 'ann95': 0.4248114868097386}
# High-reliability annotator is ann94

# %%
#considering only annotators 96,93, 94, 95
#    print(l_ann_43[i])
#l_ann_43[1]
#print(len(l_ann_96))
#print(len(df_l0))
len_lock0 = len(df_l0)
lock0_final_label = []
for i in range(0, len_lock0):
    count_true = 0
    count_false = 0
    if (l_ann_96[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_93[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_94[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_95[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        lock0_final_label.append(True)
    elif (count_false > count_true):
        lock0_final_label.append(False)
    elif (count_true == count_false):
        lock0_final_label.append(l_ann_94[i])
        
#print(lock0_final_label) 
print(len(lock0_final_label))
lock0_final_data = pd.DataFrame(data=df_l0["text"], columns = ["text"])
lock0_final_data.insert(1, 'label', lock0_final_label)
print(lock0_final_data)
# Out:
# 300
#                                                   text  label
# 0           Language Education in the Time of COVID-19  False
# 1                                   COVID-19 Test Kits  False
# 2                                   COVID 19 IN PRISON  False
# 3                                       Get Waled Home  False
# 4    Make pass/fail available for Mississippi State...  False
# 5    Governor Doug Burgum to Issue Mandatory Shelte...  False
# 6                        Early release due to covid 19  False
# 7    Medical professionals need protection and gear...  False
# 8    Save Gilroy Recreation - Theater, Aquatics, Pr...  False
# 9             Class of 2020 to get their certification  False
# 10   Calling for Disability- Inclusive Response to ...  False
# 11   Open the 2020-2021 School Year Traditionally i...  False
# 12   Save the Enhanced Nursery School Operating Gra...  False
# 13   Cancel the STAAR test for the 2020/2021 school...  False
# ...

# %%
#lock0_final_data.describe()

# %%
#eliminate annotators which are not reliable 
#change.org mask file 0
#annotators 96, 53, 93, 94, 95
if mask0_kappa_score_ann96 < 0.2:
    print("mask0_kappa_score_ann96 not reliable")
    
if mask0_kappa_score_ann53 < 0.2:
    print("mask0_kappa_score_ann53 not reliable")
    
if mask0_kappa_score_ann93 < 0.2:
    print("mask0_kappa_score_ann93 not reliable")
    
if mask0_kappa_score_ann94 < 0.2:
    print("mask0_kappa_score_ann94 not reliable")
    
if mask0_kappa_score_ann95 < 0.2:
    print("mask0_kappa_score_ann95 not reliable")

#check high reliability annotator in case of tie

high_ann_m0 ={'ann96': mask0_kappa_score_ann96, 'ann95': mask0_kappa_score_ann95}
print(high_ann_m0)
#annotator with higher reliability
high_rel_ann_m0 = max(high_ann_m0, key=high_ann_m0.get)
print("High-reliability annotator is", high_rel_ann_m0)
# Out:
# mask0_kappa_score_ann53 not reliable
# mask0_kappa_score_ann93 not reliable
# mask0_kappa_score_ann94 not reliable
# {'ann96': 0.2014534965592872, 'ann95': 0.2576172341374985}
# High-reliability annotator is ann95

# %%
#considering only annotators 96, 95

len_mask0 = len(df_m0)
mask0_final_label = []
for i in range(0, len_mask0):
    if (m_ann_95[i] == True):
        mask0_final_label.append(True)
#        count_true = count_true + 1
    else:
        mask0_final_label.append(False)
        
#print(mask0_final_label) 
print(len(mask0_final_label))
mask0_final_data = pd.DataFrame(data=df_m0["text"], columns = ["text"])
mask0_final_data.insert(1, 'label', mask0_final_label)
print(mask0_final_data)
# Out:
# 300
#                                                   text  label
# 0           Language Education in the Time of COVID-19  False
# 1                                   COVID-19 Test Kits  False
# 2                                   COVID 19 IN PRISON  False
# 3                                       Get Waled Home  False
# 4    Make pass/fail available for Mississippi State...  False
# 5    Governor Doug Burgum to Issue Mandatory Shelte...  False
# 6                        Early release due to covid 19  False
# 7    Medical professionals need protection and gear...  False
# 8    Save Gilroy Recreation - Theater, Aquatics, Pr...  False
# 9             Class of 2020 to get their certification  False
# 10   Calling for Disability- Inclusive Response to ...  False
# 11   Open the 2020-2021 School Year Traditionally i...  False
# 12   Save the Enhanced Nursery School Operating Gra...  False
# 13   Cancel the STAAR test for the 2020/2021 school...  False
# ...

# %%
print(mask0_final_label)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, 
# ...

# %%
#eliminate annotators which are not reliable 
#change.org vaccination file 0
#annotators 96, 53, 93, 94, 95
if vacc0_kappa_score_ann96 < 0.2:
    print("vacc0_kappa_score_ann96 not reliable")
    
if vacc0_kappa_score_ann53 < 0.2:
    print("vacc0_kappa_score_ann53 not reliable")
    
if vacc0_kappa_score_ann93 < 0.2:
    print("vacc0_kappa_score_ann93 not reliable")
    
if vacc0_kappa_score_ann94 < 0.2:
    print("vacc0_kappa_score_ann94 not reliable")
    
if vacc0_kappa_score_ann95 < 0.2:
    print("vacc0_kappa_score_ann95 not reliable")

#check high reliability annotator in case of tie

high_ann_v0 ={ 'ann93': vacc0_kappa_score_ann93, 'ann94': vacc0_kappa_score_ann94 }
#annotator with higher reliability
high_rel_ann_v0 = max(high_ann_v0, key=high_ann_v0.get)
print("High-reliability annotator is", high_rel_ann_v0)
# Out:
# vacc0_kappa_score_ann96 not reliable
# vacc0_kappa_score_ann53 not reliable
# vacc0_kappa_score_ann95 not reliable
# High-reliability annotator is ann93

# %%
#considering only annotators 93, 94

len_vacc0 = len(df_v0)
vacc0_final_label = []
for i in range(0, len_vacc0):
    if (v_ann_93[i] == True):
        vacc0_final_label.append(True)
    else:
        vacc0_final_label.append(False)
        
print(vacc0_final_label) 
print(len(vacc0_final_label))
vacc0_final_data = pd.DataFrame(data=df_v0["text"], columns = ["text"])
vacc0_final_data.insert(1, 'label', vacc0_final_label)
print(vacc0_final_data)
# Out:
# [False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
# ...

# %%
df_l1.describe()
# Out:
#                                                    text annotation_112  \
# count                                               300            300
# unique                                              300              2
# top     Save Altitude Trampoline Park in Spokane Valley          False
# freq                                                  1            180
#
#        annotation_109 annotation_110 annotation_111
# count             300            300            300
# unique              2              2              2
# top              True           True          False
# freq              154            186            201

# %%
#eliminate annotators which are not reliable 
#change.org lockdown file 1
#annotators 112, 109, 110, 111
if lock1_kappa_score_ann112 < 0.2:
    print("lock1_kappa_score_ann112 not reliable")
    
if lock1_kappa_score_ann109 < 0.2:
    print("lock1_kappa_score_ann109 not reliable")
    
if lock1_kappa_score_ann110 < 0.2:
    print("lock1_kappa_score_ann110 not reliable")
    
if lock1_kappa_score_ann111 < 0.2:
    print("lock1_kappa_score_ann111 not reliable")
    
#check high reliability annotator in case of tie

high_ann_l1 ={'ann112': lock1_kappa_score_ann112, 'ann109': lock1_kappa_score_ann109, 'ann110': lock1_kappa_score_ann110,  'ann111': lock1_kappa_score_ann111 }
print(high_ann_l1)
#annotator with higher reliability
high_rel_ann_l1 = max(high_ann_l1, key=high_ann_l1.get)
print("High-reliability annotator is", high_rel_ann_l1)
# Out:
# {'ann112': 0.39364100293054943, 'ann109': 0.46609505372517274, 'ann110': 0.35665361565697995, 'ann111': 0.30649557663999455}
# High-reliability annotator is ann109

# %%
#considering only annotators 96,93, 94, 95
#    print(l_ann_43[i])
#l_ann_43[1]
#print(len(l_ann_96))
#print(len(df_l0))
len_lock1 = len(df_l1)
lock1_final_label = []
for i in range(0, len_lock1):
    count_true = 0
    count_false = 0
    if (l_ann_112[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_109[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_110[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_111[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        lock1_final_label.append(True)
    elif (count_false > count_true):
        lock1_final_label.append(False)
    elif (count_true == count_false):
        lock1_final_label.append(l_ann_109[i])
#    print(count_true)
#    print(count_false)
        
print(lock1_final_label) 
print(len(lock1_final_label))
lock1_final_data = pd.DataFrame(data=df_l1["text"], columns = ["text"])
lock1_final_data.insert(1, 'label', lock1_final_label)
print(lock1_final_data)
# Out:
# [False, False, True, False, True, True, False, True, False, True, True, True, False, False, False, True, False, True, False, False, True, False, False, True, True, True, False, False, True, True, True, False, True, False, False, True, True, False, True, False, False, True, True, False, True, False, True, False, True, False, True, False, True, False, False, True, False, False, True, False, False, True, False, False, True, True, True, False, True, True, False, False, True, True, True, True, False, True, False, False, True, False, False, True, True, False, True, True, False, False, False, True, False, False, True, True, True, True, False, False, True, False, False, False, True, True, True, False, True, False, False, False, False, True, False, True, True, True, False, True, True, True, True, True, True, True, False, True, True, False, True, False, False, True, True, True, False, False, False, False, True, True, False, False, True, False, False, True, False, False, True, True, False, True
# ...

# %%
#eliminate annotators which are not reliable 
#change.org masking file 1
#annotators 112, 109, 110, 111
if mask1_kappa_score_ann112 < 0.2:
    print("mask1_kappa_score_ann112 not reliable")
    
if mask1_kappa_score_ann109 < 0.2:
    print("mask1_kappa_score_ann109 not reliable")
    
if mask1_kappa_score_ann110 < 0.2:
    print("mask1_kappa_score_ann110 not reliable")
    
if mask1_kappa_score_ann111 < 0.2:
    print("mask1_kappa_score_ann111 not reliable")
    
#check high reliability annotator in case of tie

high_ann_m1 ={'ann112': mask1_kappa_score_ann112, 'ann109': mask1_kappa_score_ann109, 'ann110': mask1_kappa_score_ann110,  'ann111': mask1_kappa_score_ann111 }
print(high_ann_m1)
#annotator with higher reliability
high_rel_ann_m1 = max(high_ann_m1, key=high_ann_m1.get)
print("High-reliability annotator is", high_rel_ann_m1)
# Out:
# {'ann112': 0.3271023526433893, 'ann109': 0.24974818844627159, 'ann110': 0.2965985925198738, 'ann111': 0.21345848907986684}
# High-reliability annotator is ann112

# %%
#considering only annotators 96,93, 94, 95
#    print(l_ann_43[i])
#l_ann_43[1]
#print(len(l_ann_96))
#print(len(df_l0))
len_mask1 = len(df_m1)
mask1_final_label = []
for i in range(0, len_mask1):
    count_true = 0
    count_false = 0
    if (m_ann_112[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_109[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_110[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_111[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        mask1_final_label.append(True)
    elif (count_false > count_true):
        mask1_final_label.append(False)
    elif (count_true == count_false):
        mask1_final_label.append(m_ann_112[i])
#    print(count_true)
#    print(count_false)
        
print(mask1_final_label) 
print(len(mask1_final_label))
mask1_final_data = pd.DataFrame(data=df_m1["text"], columns = ["text"])
mask1_final_data.insert(1, 'label', mask1_final_label)
print(mask1_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, 
# ...

# %%
#eliminate annotators which are not reliable 
#change.org vaccination file 1
#annotators 112, 109, 110, 111
if vacc1_kappa_score_ann112 < 0.2:
    print("vacc1_kappa_score_ann112 not reliable")
    
if vacc1_kappa_score_ann109 < 0.2:
    print("vacc1_kappa_score_ann109 not reliable")
    
if vacc1_kappa_score_ann110 < 0.2:
    print("vacc1_kappa_score_ann110 not reliable")
    
if vacc1_kappa_score_ann111 < 0.2:
    print("vacc1_kappa_score_ann111 not reliable")
    
#check high reliability annotator in case of tie

high_ann_v1 ={'ann112': vacc1_kappa_score_ann112, 'ann109': vacc1_kappa_score_ann109, 'ann110': vacc1_kappa_score_ann110}
print(high_ann_v1)
#annotator with higher reliability
high_rel_ann_v1 = max(high_ann_v1, key=high_ann_v1.get)
print("High-reliability annotator is", high_rel_ann_v1)
# Out:
# vacc1_kappa_score_ann111 not reliable
# {'ann112': 0.4071067270825585, 'ann109': 0.41143158404552654, 'ann110': 0.33597392235776047}
# High-reliability annotator is ann109

# %%
#considering only annotators 96,93, 94, 95
#    print(l_ann_43[i])
#l_ann_43[1]
#print(len(l_ann_96))
#print(len(df_l0))
len_vacc1 = len(df_v1)
vacc1_final_label = []
for i in range(0, len_vacc1):
    count_true = 0
    count_false = 0
    if (v_ann_112[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_109[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_110[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        vacc1_final_label.append(True)
    elif (count_false > count_true):
        vacc1_final_label.append(False)
    elif (count_true == count_false):
        vacc1_final_label.append(v_ann_109[i])
#    print(count_true)
#    print(count_false)
        
print(vacc1_final_label) 
print(len(vacc1_final_label))
vacc1_final_data = pd.DataFrame(data=df_v1["text"], columns = ["text"])
vacc1_final_data.insert(1, 'label', vacc1_final_label)
print(vacc1_final_data)
# Out:
# [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, 
# ...

# %%
df_l2.describe()
# Out:
#                                                      text annotation_73  \
# count                                                 300           300
# unique                                                300             2
# top     Hold the Chinese government accountable for CO...         False
# freq                                                    1           225
#
#        annotation_74 annotation_75 annotation_76
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             234           265           228

# %%
#eliminate annotators which are not reliable 
#change.org lockdown file 2
#annotators 73, 74, 75, 76
if lock2_kappa_score_ann73 < 0.2:
    print("lock2_kappa_score_ann73 not reliable")
    
if lock2_kappa_score_ann74 < 0.2:
    print("lock2_kappa_score_ann74 not reliable")
    
if lock2_kappa_score_ann75 < 0.2:
    print("lock2_kappa_score_ann75 not reliable")
    
if lock2_kappa_score_ann76 < 0.2:
    print("lock2_kappa_score_ann76 not reliable")
    
#check high reliability annotator in case of tie

high_ann_l2 ={'ann73': lock2_kappa_score_ann73, 'ann74': lock2_kappa_score_ann74, 'ann75': lock2_kappa_score_ann75,  'ann76': lock2_kappa_score_ann76 }
print(high_ann_l2)
#annotator with higher reliability
high_rel_ann_l2 = max(high_ann_l2, key=high_ann_l2.get)
print("High-reliability annotator is", high_rel_ann_l2)
# Out:
# {'ann73': 0.622806139472806, 'ann74': 0.6427222846004447, 'ann75': 0.47905378802347115, 'ann76': 0.6476747126970107}
# High-reliability annotator is ann76

# %%
#considering only annotators 96,93, 94, 95
#    print(l_ann_43[i])
#l_ann_43[1]
#print(len(l_ann_96))
#print(len(df_l0))
len_lock2 = len(df_l2)
lock2_final_label = []
for i in range(0, len_lock2):
    count_true = 0
    count_false = 0
    if (l_ann_73[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_74[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_75[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_76[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        lock2_final_label.append(True)
    elif (count_false > count_true):
        lock2_final_label.append(False)
    elif (count_true == count_false):
        lock2_final_label.append(l_ann_76[i])
#    print(count_true)
#    print(count_false)
        
print(lock2_final_label) 
print(len(lock2_final_label))
lock2_final_data = pd.DataFrame(data=df_l2["text"], columns = ["text"])
lock2_final_data.insert(1, 'label', lock2_final_label)
print(lock2_final_data)
# Out:
# [False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, True, False, False, True, False, False, True, False, False, False, False, False, True, False, True, False, False, True, False, False, True, True, False, False, False, False, False, True, False, False, True, False, True, False, False, True, False, True, False, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False,
# ...

# %%
#eliminate annotators which are not reliable 
#change.org masking file 2
#annotators 73, 74, 75, 76
if mask2_kappa_score_ann73 < 0.2:
    print("mask2_kappa_score_ann73 not reliable")
    
if mask2_kappa_score_ann74 < 0.2:
    print("mask2_kappa_score_ann74 not reliable")
    
if mask2_kappa_score_ann75 < 0.2:
    print("mask2_kappa_score_ann75 not reliable")
    
if mask2_kappa_score_ann76 < 0.2:
    print("mask2_kappa_score_ann76 not reliable")
    
#check high reliability annotator in case of tie

high_ann_m2 ={'ann73': mask2_kappa_score_ann73, 'ann74': mask2_kappa_score_ann74, 'ann75': mask2_kappa_score_ann75,  'ann76': mask2_kappa_score_ann76 }
print(high_ann_m2)
#annotator with higher reliability
high_rel_ann_m2 = max(high_ann_m2, key=high_ann_m2.get)
print("High-reliability annotator is", high_rel_ann_m2)
# Out:
# mask2_kappa_score_ann75 not reliable
# mask2_kappa_score_ann76 not reliable
# {'ann73': 0.20377207915199477, 'ann74': 0.22058691129610516, 'ann75': 0.0, 'ann76': 0.19804460560689363}
# High-reliability annotator is ann74

# %%
#considering only reliable annotators
len_mask2 = len(df_m2)
mask2_final_label = []
for i in range(0, len_mask2):
    if (m_ann_74[i] == True):
        mask2_final_label.append(True)
    else:
        mask2_final_label.append(False)
        
#    print(count_true)
#    print(count_false)
        
print(mask2_final_label) 
print(len(mask2_final_label))
mask2_final_data = pd.DataFrame(data=df_m2["text"], columns = ["text"])
mask2_final_data.insert(1, 'label', mask2_final_label)
print(mask2_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, True, False, F
# ...

# %%
#eliminate annotators which are not reliable 
#change.org vaccination file 2
#annotators 73, 74, 75, 76
if vacc2_kappa_score_ann73 < 0.2:
    print("vacc2_kappa_score_ann73 not reliable")
    
if vacc2_kappa_score_ann74 < 0.2:
    print("vacc2_kappa_score_ann74 not reliable")
    
if vacc2_kappa_score_ann75 < 0.2:
    print("vacc2_kappa_score_ann75 not reliable")
    
if vacc2_kappa_score_ann76 < 0.2:
    print("vacc2_kappa_score_ann76 not reliable")
    
#check high reliability annotator in case of tie

high_ann_v2 ={'ann73': vacc2_kappa_score_ann73, 'ann74': vacc2_kappa_score_ann74, 'ann75': vacc2_kappa_score_ann75,  'ann76': vacc2_kappa_score_ann76 }
print(high_ann_v2)
#annotator with higher reliability
high_rel_ann_v2 = max(high_ann_v2, key=high_ann_v2.get)
print("High-reliability annotator is", high_rel_ann_v2)
# Out:
# {'ann73': 0.6519690422129448, 'ann74': 0.7854252367909931, 'ann75': 0.5834154561380728, 'ann76': 0.7501466670105877}
# High-reliability annotator is ann74

# %%
#considering only annotators 96,93, 94, 95
#    print(l_ann_43[i])
#l_ann_43[1]
#print(len(l_ann_96))
#print(len(df_l0))
len_vacc2 = len(df_v2)
vacc2_final_label = []
for i in range(0, len_vacc2):
    count_true = 0
    count_false = 0
    if (v_ann_73[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_74[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_75[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_76[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        vacc2_final_label.append(True)
    elif (count_false > count_true):
        vacc2_final_label.append(False)
    elif (count_true == count_false):
        vacc2_final_label.append(v_ann_76[i])
#    print(count_true)
#    print(count_false)
        
print(vacc2_final_label) 
print(len(vacc2_final_label))
vacc2_final_data = pd.DataFrame(data=df_v2["text"], columns = ["text"])
vacc2_final_data.insert(1, 'label', vacc2_final_label)
print(vacc2_final_data)
# Out:
# [False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
# ...

# %%
df_l3.describe()
# Out:
#                 text annotation_48 annotation_49 annotation_50 annotation_47
# count            300           300           300           300           300
# unique           300             2             2             2             2
# top     Save Schmidt         False         False         False         False
# freq               1           166           245           235           166

# %%
#eliminate annotators which are not reliable 
#change.org lockdown file 3
#annotators 48, 49, 50, 47
if lock3_kappa_score_ann48 < 0.2:
    print("lock3_kappa_score_ann48 not reliable")
    
if lock3_kappa_score_ann49 < 0.2:
    print("lock3_kappa_score_ann49 not reliable")
    
if lock3_kappa_score_ann50 < 0.2:
    print("lock3_kappa_score_ann50 not reliable")
    
if lock3_kappa_score_ann47 < 0.2:
    print("lock3_kappa_score_ann47 not reliable")
    
#check high reliability annotator in case of tie

high_ann_l3 ={'ann48': lock3_kappa_score_ann48, 'ann49': lock3_kappa_score_ann49, 'ann50': lock3_kappa_score_ann50,  'ann47': lock3_kappa_score_ann47 }
print(high_ann_l3)
#annotator with higher reliability
high_rel_ann_l3 = max(high_ann_l3, key=high_ann_l3.get)
print("High-reliability annotator is", high_rel_ann_l3)
# Out:
# {'ann48': 0.4200460114235917, 'ann49': 0.4371382830557451, 'ann50': 0.45454008844232313, 'ann47': 0.43423711832993034}
# High-reliability annotator is ann50

# %%
#considering only reliable annotators 

len_lock3 = len(df_l3)
lock3_final_label = []
for i in range(0, len_lock3):
    count_true = 0
    count_false = 0
    if (l_ann_48[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_49[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_50[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_47[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        lock3_final_label.append(True)
    elif (count_false > count_true):
        lock3_final_label.append(False)
    elif (count_true == count_false):
        lock3_final_label.append(l_ann_50[i])
#    print(count_true)
#    print(count_false)
        
print(lock3_final_label) 
print(len(lock3_final_label))
lock3_final_data = pd.DataFrame(data=df_l3["text"], columns = ["text"])
lock3_final_data.insert(1, 'label', lock3_final_label)
print(lock3_final_data)
# Out:
# [False, False, True, False, False, True, True, False, False, False, False, True, False, False, True, False, True, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, True, False, False, True, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, True, False, False, False, False, False, True, False, True, False, False, True, False, False, False, False, False, True, False, False, False, True, True, False, True, False, True, False, False, True, False, False, False, False, False, False, True, False, False, True, False, True, Fa
# ...

# %%
#eliminate annotators which are not reliable 
#change.org masking file 3
#annotators 48, 49, 50, 47
if mask3_kappa_score_ann48 < 0.2:
    print("mask3_kappa_score_ann48 not reliable")
    
if mask3_kappa_score_ann49 < 0.2:
    print("mask3_kappa_score_ann49 not reliable")
    
if mask3_kappa_score_ann50 < 0.2:
    print("mask3_kappa_score_ann50 not reliable")
    
if mask3_kappa_score_ann47 < 0.2:
    print("mask3_kappa_score_ann47 not reliable")
    
#check high reliability annotator in case of tie

high_ann_m3 ={'ann48': mask3_kappa_score_ann48, 'ann49': mask3_kappa_score_ann49, 'ann50': mask3_kappa_score_ann50,  'ann47': mask3_kappa_score_ann47 }
print(high_ann_m3)
#annotator with higher reliability
high_rel_ann_m3 = max(high_ann_m3, key=high_ann_m3.get)
print("High-reliability annotator is", high_rel_ann_m3)
# Out:
# {'ann48': 0.3646427764050817, 'ann49': 0.49366428625005804, 'ann50': 0.4672559392890074, 'ann47': 0.4033470237744203}
# High-reliability annotator is ann49

# %%
#considering only reliable annotators 

len_mask3 = len(df_m3)
mask3_final_label = []
for i in range(0, len_mask3):
    count_true = 0
    count_false = 0
    if (m_ann_48[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_49[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_50[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_47[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        mask3_final_label.append(True)
    elif (count_false > count_true):
        mask3_final_label.append(False)
    elif (count_true == count_false):
        mask3_final_label.append(m_ann_49[i])
#    print(count_true)
#    print(count_false)
        
print(mask3_final_label) 
print(len(mask3_final_label))
mask3_final_data = pd.DataFrame(data=df_m3["text"], columns = ["text"])
mask3_final_data.insert(1, 'label', mask3_final_label)
print(mask3_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, Fal
# ...

# %%
#eliminate annotators which are not reliable 
#change.org vaccination file 3
#annotators 48, 49, 50, 47
if vacc3_kappa_score_ann48 < 0.2:
    print("vacc3_kappa_score_ann48 not reliable")
    
if vacc3_kappa_score_ann49 < 0.2:
    print("vacc3_kappa_score_ann49 not reliable")
    
if vacc3_kappa_score_ann50 < 0.2:
    print("vacc3_kappa_score_ann50 not reliable")
    
if vacc3_kappa_score_ann47 < 0.2:
    print("vacc3_kappa_score_ann47 not reliable")
    
#check high reliability annotator in case of tie

high_ann_v3 ={'ann48': vacc3_kappa_score_ann48, 'ann49': vacc3_kappa_score_ann49, 'ann50': vacc3_kappa_score_ann50,  'ann47': vacc3_kappa_score_ann47 }
print(high_ann_v3)
#annotator with higher reliability
high_rel_ann_v3 = max(high_ann_v3, key=high_ann_v3.get)
print("High-reliability annotator is", high_rel_ann_v3)
# Out:
# {'ann48': 0.3876597393675265, 'ann49': 0.6049309337905934, 'ann50': 0.5622891963427569, 'ann47': 0.5241054451580767}
# High-reliability annotator is ann49

# %%
#considering only reliable annotators 

len_vacc3 = len(df_v3)
vacc3_final_label = []
for i in range(0, len_vacc3):
    count_true = 0
    count_false = 0
    if (v_ann_48[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_49[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_50[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_47[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        vacc3_final_label.append(True)
    elif (count_false > count_true):
        vacc3_final_label.append(False)
    elif (count_true == count_false):
        vacc3_final_label.append(v_ann_49[i])
#    print(count_true)
#    print(count_false)
        
print(vacc3_final_label) 
print(len(vacc3_final_label))
vacc3_final_data = pd.DataFrame(data=df_v3["text"], columns = ["text"])
vacc3_final_data.insert(1, 'label', vacc3_final_label)
print(vacc3_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False
# ...

# %%
df_l4.describe()
# Out:
#                                         text annotation_43 annotation_44  \
# count                                    300           300           300
# unique                                   300             2             2
# top     Stop Increasing Rent During COVID-19          True         False
# freq                                       1           245           250
#
#        annotation_45 annotation_46
# count            300           300
# unique             2             2
# top            False         False
# freq             201           226

# %%
#eliminate annotators which are not reliable 
#change.org lockdown file 4
#annotators 43, 44, 45, 46
if lock4_kappa_score_ann43 < 0.2:
    print("lock4_kappa_score_ann43 not reliable")
    
if lock4_kappa_score_ann44 < 0.2:
    print("lock4_kappa_score_ann44 not reliable")
    
if lock4_kappa_score_ann45 < 0.2:
    print("lock4_kappa_score_ann45 not reliable")
    
if lock4_kappa_score_ann46 < 0.2:
    print("lock4_kappa_score_ann46 not reliable")
    
#check high reliability annotator in case of tie

high_ann_l4 ={'ann44': lock4_kappa_score_ann44, 'ann45': lock4_kappa_score_ann45,  'ann46': lock4_kappa_score_ann46 }
print(high_ann_l4)
#annotator with higher reliability
high_rel_ann_l4 = max(high_ann_l4, key=high_ann_l4.get)
print("High-reliability annotator is", high_rel_ann_l4)
# Out:
# lock4_kappa_score_ann43 not reliable
# {'ann44': 0.36010628808917683, 'ann45': 0.38002727513320894, 'ann46': 0.38613193821237113}
# High-reliability annotator is ann46

# %%
#considering only reliable annotators 

len_lock4 = len(df_l4)
lock4_final_label = []
for i in range(0, len_lock4):
    count_true = 0
    count_false = 0
    if (l_ann_44[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_45[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_46[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        lock4_final_label.append(True)
    elif (count_false > count_true):
        lock4_final_label.append(False)
    elif (count_true == count_false):
        lock4_final_label.append(l_ann_46[i])
#    print(count_true)
#    print(count_false)
        
print(lock4_final_label) 
print(len(lock4_final_label))
lock4_final_data = pd.DataFrame(data=df_l4["text"], columns = ["text"])
lock4_final_data.insert(1, 'label', lock4_final_label)
print(lock4_final_data)
# Out:
# [False, False, False, False, False, False, True, False, False, True, False, True, True, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, True, True, True, False, False, False, False, True, False, False, False, False, True, False, True, False, True, False, True, False, False, False, True, False, True, True, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, 
# ...

# %%
#eliminate annotators which are not reliable 
#change.org masking file 4
#annotators 43, 44, 45, 46
if mask4_kappa_score_ann43 < 0.2:
    print("mask4_kappa_score_ann43 not reliable")
    
if mask4_kappa_score_ann44 < 0.2:
    print("mask4_kappa_score_ann44 not reliable")
    
if mask4_kappa_score_ann45 < 0.2:
    print("mask4_kappa_score_ann45 not reliable")
    
if mask4_kappa_score_ann46 < 0.2:
    print("mask4_kappa_score_ann46 not reliable")
    
#check high reliability annotator in case of tie

high_ann_m4 ={'ann43': mask4_kappa_score_ann43, 'ann44': mask4_kappa_score_ann44, 'ann45': mask4_kappa_score_ann45,  'ann46': mask4_kappa_score_ann46 }
print(high_ann_m4)
#annotator with higher reliability
high_rel_ann_m4 = max(high_ann_m4, key=high_ann_m4.get)
print("High-reliability annotator is", high_rel_ann_m4)
# Out:
# {'ann43': 0.2050467381297456, 'ann44': 0.3750365569505501, 'ann45': 0.4517290066893758, 'ann46': 0.38693576068206964}
# High-reliability annotator is ann45

# %%
#considering only reliable annotators 

len_mask4 = len(df_m4)
mask4_final_label = []
for i in range(0, len_mask4):
    count_true = 0
    count_false = 0
    if (m_ann_43[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_44[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_45[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_46[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        mask4_final_label.append(True)
    elif (count_false > count_true):
        mask4_final_label.append(False)
    elif (count_true == count_false):
        mask4_final_label.append(m_ann_45[i])
#    print(count_true)
#    print(count_false)
        
print(mask4_final_label) 
print(len(mask4_final_label))
mask4_final_data = pd.DataFrame(data=df_m4["text"], columns = ["text"])
mask4_final_data.insert(1, 'label', mask4_final_label)
print(mask4_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False
# ...

# %%
#eliminate annotators which are not reliable 
#change.org vaccination file 4
#annotators 43, 44, 45, 46
if vacc4_kappa_score_ann43 < 0.2:
    print("vacc4_kappa_score_ann43 not reliable")
    
if vacc4_kappa_score_ann44 < 0.2:
    print("vacc4_kappa_score_ann44 not reliable")
    
if vacc4_kappa_score_ann45 < 0.2:
    print("vacc4_kappa_score_ann45 not reliable")
    
if vacc4_kappa_score_ann46 < 0.2:
    print("vacc4_kappa_score_ann46 not reliable")
    
#check high reliability annotator in case of tie

high_ann_v4 ={'ann43': vacc4_kappa_score_ann43, 'ann44': vacc4_kappa_score_ann44, 'ann45': vacc4_kappa_score_ann45,  'ann46': vacc4_kappa_score_ann46 }
print(high_ann_v4)
#annotator with higher reliability
high_rel_ann_v4 = max(high_ann_v4, key=high_ann_v4.get)
print("High-reliability annotator is", high_rel_ann_v4)
# Out:
# {'ann43': 0.5267395021958605, 'ann44': 0.7344262383224409, 'ann45': 0.751427803587239, 'ann46': 0.6674261993660947}
# High-reliability annotator is ann45

# %%
#considering only reliable annotators 

len_vacc4 = len(df_v4)
vacc4_final_label = []
for i in range(0, len_vacc4):
    count_true = 0
    count_false = 0
    if (v_ann_43[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_44[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_45[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_46[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        vacc4_final_label.append(True)
    elif (count_false > count_true):
        vacc4_final_label.append(False)
    elif (count_true == count_false):
        vacc4_final_label.append(v_ann_45[i])
#    print(count_true)
#    print(count_false)
        
print(vacc4_final_label) 
print(len(vacc4_final_label))
vacc4_final_data = pd.DataFrame(data=df_v4["text"], columns = ["text"])
vacc4_final_data.insert(1, 'label', vacc4_final_label)
print(vacc4_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False
# ...

# %%
#twitter data
tw_df_l0.describe()
# Out:
#                                                      text annotation_104  \
# count                                                 300            300
# unique                                                300              2
# top     I don’t think now is a good time to get arrest...          False
# freq                                                    1            262
#
#        annotation_101 annotation_102 annotation_103
# count             300            300            300
# unique              2              2              2
# top             False          False          False
# freq              286            297            297

# %%
#eliminate annotators which are not reliable 
#twitter lockdown file 0
#annotators 104, 101, 102, 103
if lock0_kappa_score_ann104 < 0.2:
    print("lock0_kappa_score_ann104 not reliable")
    
if lock0_kappa_score_ann101 < 0.2:
    print("lock0_kappa_score_ann101 not reliable")
    
if lock0_kappa_score_ann102 < 0.2:
    print("lock0_kappa_score_ann102 not reliable")
    
if lock0_kappa_score_ann103 < 0.2:
    print("lock0_kappa_score_ann103 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_l0 ={'ann101': lock0_kappa_score_ann101, 'ann102': lock0_kappa_score_ann103}
print(t_high_ann_l0)
#annotator with higher reliability
t_high_rel_ann_l0 = max(t_high_ann_l0, key=t_high_ann_l0.get)
print("High-reliability annotator is", t_high_rel_ann_l0)
# Out:
# lock0_kappa_score_ann104 not reliable
# lock0_kappa_score_ann102 not reliable
# {'ann101': 0.20788424756793666, 'ann102': 0.20986808782839614}
# High-reliability annotator is ann102

# %%
#considering only reliable annotators 
t_len_lock0 = len(tw_df_l0)
t_lock0_final_label = []
for i in range(0, t_len_lock0):
    if (l_ann_102[i] == True):
        t_lock0_final_label.append(True)
    else:
        t_lock0_final_label.append(False)
        
print(t_lock0_final_label) 
print(len(t_lock0_final_label))
t_lock0_final_data = pd.DataFrame(data=tw_df_l0["text"], columns = ["text"])
t_lock0_final_data.insert(1, 'label', t_lock0_final_label)
print(t_lock0_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False
# ...

# %%
tw_df_m0.describe()
# Out:
#                                                      text annotation_104  \
# count                                                 300            300
# unique                                                300              2
# top     I don’t think now is a good time to get arrest...          False
# freq                                                    1            180
#
#        annotation_101 annotation_102 annotation_103
# count             300            300            300
# unique              2              2              2
# top             False          False          False
# freq              241            236            239

# %%
#eliminate annotators which are not reliable 
#twitter masking file 0
#annotators 104, 101, 102, 103
if mask0_kappa_score_ann104 < 0.2:
    print("mask0_kappa_score_ann104 not reliable")
    
if mask0_kappa_score_ann101 < 0.2:
    print("mask0_kappa_score_ann101 not reliable")
    
if mask0_kappa_score_ann102 < 0.2:
    print("mask0_kappa_score_ann102 not reliable")
    
if mask0_kappa_score_ann103 < 0.2:
    print("mask0_kappa_score_ann103 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_m0 ={'ann104': mask0_kappa_score_ann104, 'ann101': mask0_kappa_score_ann101, 'ann102': mask0_kappa_score_ann102, 'ann103': mask0_kappa_score_ann103}
print(t_high_ann_m0)
#annotator with higher reliability
t_high_rel_ann_m0 = max(t_high_ann_m0, key=t_high_ann_m0.get)
print("High-reliability annotator is", t_high_rel_ann_m0)
# Out:
# {'ann104': 0.5110966318263074, 'ann101': 0.7704815888817947, 'ann102': 0.7327868362752801, 'ann103': 0.7630634070755388}
# High-reliability annotator is ann101

# %%
#considering only reliable annotators 
t_len_mask0 = len(tw_df_m0)
t_mask0_final_label = []
for i in range(0, t_len_mask0):
    count_true = 0
    count_false = 0
    if (m_ann_104[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_101[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_102[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_103[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_mask0_final_label.append(True)
    elif (count_false > count_true):
        t_mask0_final_label.append(False)
    elif (count_true == count_false):
        t_mask0_final_label.append(m_ann_101[i])
    
print(t_mask0_final_label) 
print(len(t_mask0_final_label))
t_mask0_final_data = pd.DataFrame(data=tw_df_m0["text"], columns = ["text"])
t_mask0_final_data.insert(1, 'label', t_mask0_final_label)
print(t_mask0_final_data)
# Out:
# [False, False, False, False, True, False, True, True, True, False, False, False, False, True, False, False, False, True, False, False, False, True, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, False, False, False, True, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, True, False, False, False, False, False, Tr
# ...

# %%
#eliminate annotators which are not reliable 
#twitter vaccination file 0
#annotators 104, 101, 102, 103
if vacc0_kappa_score_ann104 < 0.2:
    print("vacc0_kappa_score_ann104 not reliable")
    
if vacc0_kappa_score_ann101 < 0.2:
    print("vacc0_kappa_score_ann101 not reliable")
    
if vacc0_kappa_score_ann102 < 0.2:
    print("vacc0_kappa_score_ann102 not reliable")
    
if vacc0_kappa_score_ann103 < 0.2:
    print("vacc0_kappa_score_ann103 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_v0 ={'ann104': vacc0_kappa_score_ann104, 'ann101': vacc0_kappa_score_ann101, 'ann102': vacc0_kappa_score_ann102, 'ann103': vacc0_kappa_score_ann103}
print(t_high_ann_v0)
#annotator with higher reliability
t_high_rel_ann_v0 = max(t_high_ann_v0, key=t_high_ann_v0.get)
print("High-reliability annotator is", t_high_rel_ann_v0)
# Out:
# {'ann104': 0.673287439979103, 'ann101': 0.7621309462828351, 'ann102': 0.6241408556645266, 'ann103': 0.7095627314652487}
# High-reliability annotator is ann101

# %%
#considering only reliable annotators 
t_len_vacc0 = len(tw_df_v0)
t_vacc0_final_label = []
for i in range(0, t_len_vacc0):
    count_true = 0
    count_false = 0
    if (v_ann_104[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_101[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_102[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_103[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_vacc0_final_label.append(True)
    elif (count_false > count_true):
        t_vacc0_final_label.append(False)
    elif (count_true == count_false):
        t_vacc0_final_label.append(v_ann_101[i])
    
print(t_vacc0_final_label) 
print(len(t_vacc0_final_label))
t_vacc0_final_data = pd.DataFrame(data=tw_df_m0["text"], columns = ["text"])
t_vacc0_final_data.insert(1, 'label', t_vacc0_final_label)
print(t_vacc0_final_data)
# Out:
# [True, True, True, False, True, True, False, True, True, True, True, False, True, True, False, True, True, False, True, True, True, True, True, False, False, True, True, False, False, True, False, True, False, True, False, True, True, False, True, True, False, True, False, True, False, True, True, True, True, False, True, True, False, True, True, False, False, False, False, True, False, False, False, False, True, True, True, True, True, True, True, False, False, False, True, False, True, True, True, False, False, False, False, True, True, False, False, False, True, False, False, True, True, True, True, True, True, True, True, False, False, True, False, True, True, False, True, True, False, True, True, True, False, False, True, False, True, False, False, False, True, False, True, True, False, False, False, False, False, True, False, False, False, False, True, True, False, True, True, False, True, False, True, False, False, True, False, True, False, False, True, True, True, True, True,
# ...

# %%
tw_df_l1.describe()
# Out:
#                                                      text annotation_51  \
# count                                                 300           300
# unique                                                300             2
# top     This #Individualism shit might make it so we n...         False
# freq                                                    1           270
#
#        annotation_52 annotation_53 annotation_54
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             281           279           278

# %%
#eliminate annotators which are not reliable 
#twitter lockdown file 1
#annotators 51, 52, 53, 54
if lock1_kappa_score_ann51 < 0.2:
    print("lock1_kappa_score_ann51 not reliable")
    
if lock1_kappa_score_ann52 < 0.2:
    print("lock1_kappa_score_ann52 not reliable")
    
if lock1_kappa_score_ann53 < 0.2:
    print("lock1_kappa_score_ann53 not reliable")
    
if lock1_kappa_score_ann54 < 0.2:
    print("lock1_kappa_score_ann54 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_l1 ={'ann51': lock1_kappa_score_ann51, 'ann52': lock1_kappa_score_ann52, 'ann53': lock1_kappa_score_ann53, 'ann54': lock1_kappa_score_ann54}
print(t_high_ann_l1)
#annotator with higher reliability
t_high_rel_ann_l1 = max(t_high_ann_l1, key=t_high_ann_l1.get)
print("High-reliability annotator is", t_high_rel_ann_l1)
# Out:
# {'ann51': 0.38374396729420157, 'ann52': 0.2475066127986606, 'ann53': 0.3466783318742191, 'ann54': 0.3615994589823533}
# High-reliability annotator is ann51

# %%
#considering only reliable annotators 
t_len_lock1 = len(tw_df_l1)
t_lock1_final_label = []
for i in range(0, t_len_lock1):
    count_true = 0
    count_false = 0
    if (l_ann_51[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_52[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_53[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_54[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_lock1_final_label.append(True)
    elif (count_false > count_true):
        t_lock1_final_label.append(False)
    elif (count_true == count_false):
        t_lock1_final_label.append(l_ann_51[i])
    
print(t_lock1_final_label) 
print(len(t_lock1_final_label))
t_lock1_final_data = pd.DataFrame(data=tw_df_l1["text"], columns = ["text"])
t_lock1_final_data.insert(1, 'label', t_lock1_final_label)
print(t_lock1_final_data)
# Out:
# [False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, F
# ...

# %%
#eliminate annotators which are not reliable 
#twitter masking file 1
#annotators 51, 52, 53, 54
if mask1_kappa_score_ann51 < 0.2:
    print("mask1_kappa_score_ann51 not reliable")
    
if mask1_kappa_score_ann52 < 0.2:
    print("mask1_kappa_score_ann52 not reliable")
    
if mask1_kappa_score_ann53 < 0.2:
    print("mask1_kappa_score_ann53 not reliable")
    
if mask1_kappa_score_ann54 < 0.2:
    print("mask1_kappa_score_ann54 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_m1 ={'ann51': mask1_kappa_score_ann51, 'ann52': mask1_kappa_score_ann52, 'ann53': mask1_kappa_score_ann53, 'ann54': mask1_kappa_score_ann54}
print(t_high_ann_m1)
#annotator with higher reliability
t_high_rel_ann_m1 = max(t_high_ann_m1, key=t_high_ann_m1.get)
print("High-reliability annotator is", t_high_rel_ann_m1)
# Out:
# {'ann51': 0.5547693664516317, 'ann52': 0.6992497233396247, 'ann53': 0.6807204926375218, 'ann54': 0.7045924598892853}
# High-reliability annotator is ann54

# %%
#considering only reliable annotators 
t_len_mask1 = len(tw_df_m1)
t_mask1_final_label = []
for i in range(0, t_len_mask1):
    count_true = 0
    count_false = 0
    if (m_ann_51[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_52[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_53[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_54[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_mask1_final_label.append(True)
    elif (count_false > count_true):
        t_mask1_final_label.append(False)
    elif (count_true == count_false):
        t_mask1_final_label.append(m_ann_51[i])
    
print(t_mask1_final_label) 
print(len(t_mask1_final_label))
t_mask1_final_data = pd.DataFrame(data=tw_df_m1["text"], columns = ["text"])
t_mask1_final_data.insert(1, 'label', t_mask1_final_label)
print(t_mask1_final_data)
# Out:
# [True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, True, True, False, False, True, True, False, False, False, True, False, False, False, True, False, False, False, False, False, False, True, False, False, False, True, False, False, False, True, False, False, False, True, False, False, True, True, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False,
# ...

# %%
#eliminate annotators which are not reliable 
#twitter vaccination file 1
#annotators 51, 52, 53, 54
if vacc1_kappa_score_ann51 < 0.2:
    print("vacc1_kappa_score_ann51 not reliable")
    
if vacc1_kappa_score_ann52 < 0.2:
    print("vacc1_kappa_score_ann52 not reliable")
    
if vacc1_kappa_score_ann53 < 0.2:
    print("vacc1_kappa_score_ann53 not reliable")
    
if vacc1_kappa_score_ann54 < 0.2:
    print("vacc1_kappa_score_ann54 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_v1 ={'ann51': vacc1_kappa_score_ann51, 'ann52': vacc1_kappa_score_ann52, 'ann53': vacc1_kappa_score_ann53, 'ann54': vacc1_kappa_score_ann54}
print(t_high_ann_v1)
#annotator with higher reliability
t_high_rel_ann_v1 = max(t_high_ann_v1, key=t_high_ann_v1.get)
print("High-reliability annotator is", t_high_rel_ann_v1)
# Out:
# {'ann51': 0.6557455942279518, 'ann52': 0.3626159972414958, 'ann53': 0.6134981271639437, 'ann54': 0.6083138882680158}
# High-reliability annotator is ann51

# %%
#considering only reliable annotators 
t_len_vacc1 = len(tw_df_v1)
t_vacc1_final_label = []
for i in range(0, t_len_vacc1):
    count_true = 0
    count_false = 0
    if (v_ann_51[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_52[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_53[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_54[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_vacc1_final_label.append(True)
    elif (count_false > count_true):
        t_vacc1_final_label.append(False)
    elif (count_true == count_false):
        t_vacc1_final_label.append(v_ann_51[i])
    
print(t_vacc1_final_label) 
print(len(t_vacc1_final_label))
t_vacc1_final_data = pd.DataFrame(data=tw_df_v1["text"], columns = ["text"])
t_vacc1_final_data.insert(1, 'label', t_vacc1_final_label)
print(t_vacc1_final_data)
# Out:
# [False, False, True, False, False, False, True, True, True, True, False, True, False, True, True, False, True, True, False, True, True, True, True, True, False, True, True, True, False, True, True, False, True, True, True, False, False, False, False, True, False, True, False, True, False, True, False, False, True, True, False, False, True, True, True, True, False, False, False, True, True, True, False, False, True, False, True, False, True, False, True, False, False, True, True, False, True, False, False, True, False, True, True, False, True, True, True, True, True, True, True, True, False, False, True, False, False, True, True, False, False, True, True, True, False, True, False, True, False, False, True, True, False, True, True, True, True, False, True, True, True, True, False, False, False, True, True, True, True, True, False, False, False, True, True, True, False, True, True, True, True, False, True, False, False, True, True, True, True, True, True, False, False, True, False, True
# ...

# %%
tw_df_l2.describe()
# Out:
#                                                      text annotation_56  \
# count                                                 300           300
# unique                                                300             2
# top     It will probably be compulsory here too. Why e...         False
# freq                                                    1           194
#
#        annotation_57 annotation_58 annotation_59
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             291           249           289

# %%
#eliminate annotators which are not reliable 
#twitter lockdown file 2
#annotators 56, 57, 58, 59
if lock2_kappa_score_ann56 < 0.2:
    print("lock2_kappa_score_ann56 not reliable")
    
if lock2_kappa_score_ann57 < 0.2:
    print("lock2_kappa_score_ann57 not reliable")
    
if lock2_kappa_score_ann58 < 0.2:
    print("lock2_kappa_score_ann58 not reliable")
    
if lock2_kappa_score_ann59 < 0.2:
    print("lock2_kappa_score_ann59 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_l2 ={'ann57': lock2_kappa_score_ann57, 'ann59': lock2_kappa_score_ann59}
print(t_high_ann_l2)
#annotator with higher reliability
t_high_rel_ann_l2 = max(t_high_ann_l2, key=t_high_ann_l2.get)
print("High-reliability annotator is", t_high_rel_ann_l2)
# Out:
# lock2_kappa_score_ann56 not reliable
# lock2_kappa_score_ann58 not reliable
# {'ann57': 0.30077990922116665, 'ann59': 0.30290799595403145}
# High-reliability annotator is ann59

# %%
#considering only reliable annotators 
t_len_lock2 = len(tw_df_l2)
t_lock2_final_label = []
for i in range(0, t_len_lock2): 
    if (l_ann_59[i] == True):
        t_lock2_final_label.append(True)
    else:
        t_lock2_final_label.append(False)
    
print(t_lock2_final_label) 
print(len(t_lock2_final_label))
t_lock2_final_data = pd.DataFrame(data=tw_df_l2["text"], columns = ["text"])
t_lock2_final_data.insert(1, 'label', t_lock2_final_label)
print(t_lock2_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, 
# ...

# %%
#eliminate annotators which are not reliable 
#twitter masking file 2
#annotators 56, 57, 58, 59
if mask2_kappa_score_ann56 < 0.2:
    print("mask2_kappa_score_ann56 not reliable")
    
if mask2_kappa_score_ann57 < 0.2:
    print("mask2_kappa_score_ann57 not reliable")
    
if mask2_kappa_score_ann58 < 0.2:
    print("mask2_kappa_score_ann58 not reliable")
    
if mask2_kappa_score_ann59 < 0.2:
    print("mask2_kappa_score_ann59 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_m2 ={'ann56': mask2_kappa_score_ann56, 'ann57': mask2_kappa_score_ann57, 'ann58': mask2_kappa_score_ann58, 'ann59': mask2_kappa_score_ann59}
print(t_high_ann_m2)
#annotator with higher reliability
t_high_rel_ann_m2 = max(t_high_ann_m2, key=t_high_ann_m2.get)
print("High-reliability annotator is", t_high_rel_ann_m2)
# Out:
# {'ann56': 0.6346300788322754, 'ann57': 0.6029432092245662, 'ann58': 0.5641640469267309, 'ann59': 0.6629464534041484}
# High-reliability annotator is ann59

# %%
#considering only reliable annotators 
t_len_mask2 = len(tw_df_m2)
t_mask2_final_label = []
for i in range(0, t_len_mask2):
    count_true = 0
    count_false = 0
    if (m_ann_56[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_57[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_58[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_59[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_mask2_final_label.append(True)
    elif (count_false > count_true):
        t_mask2_final_label.append(False)
    elif (count_true == count_false):
        t_mask2_final_label.append(m_ann_59[i])
    
print(t_mask2_final_label) 
print(len(t_mask2_final_label))
t_mask2_final_data = pd.DataFrame(data=tw_df_m2["text"], columns = ["text"])
t_mask2_final_data.insert(1, 'label', t_mask2_final_label)
print(t_mask2_final_data)
# Out:
# [True, False, False, True, False, True, True, False, False, False, False, True, False, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, True, True, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, Tr
# ...

# %%
#eliminate annotators which are not reliable 
#twitter vaccination file 2
#annotators 56, 57, 58, 59
if vacc2_kappa_score_ann56 < 0.2:
    print("vacc2_kappa_score_ann56 not reliable")
    
if vacc2_kappa_score_ann57 < 0.2:
    print("vacc2_kappa_score_ann57 not reliable")
    
if vacc2_kappa_score_ann58 < 0.2:
    print("vacc2_kappa_score_ann58 not reliable")
    
if vacc2_kappa_score_ann59 < 0.2:
    print("vacc2_kappa_score_ann59 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_v2 ={'ann56': vacc2_kappa_score_ann56, 'ann57': vacc2_kappa_score_ann57, 'ann58': vacc2_kappa_score_ann58, 'ann59': vacc2_kappa_score_ann59}
print(t_high_ann_v2)
#annotator with higher reliability
t_high_rel_ann_v2 = max(t_high_ann_v2, key=t_high_ann_v2.get)
print("High-reliability annotator is", t_high_rel_ann_v2)
# Out:
# {'ann56': 0.6901550441139593, 'ann57': 0.6946177360097107, 'ann58': 0.5853754265879894, 'ann59': 0.7371881632778615}
# High-reliability annotator is ann59

# %%
#considering only reliable annotators 
t_len_vacc2 = len(tw_df_v2)
t_vacc2_final_label = []
for i in range(0, t_len_vacc2):
    count_true = 0
    count_false = 0
    if (v_ann_56[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_57[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_58[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_59[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_vacc2_final_label.append(True)
    elif (count_false > count_true):
        t_vacc2_final_label.append(False)
    elif (count_true == count_false):
        t_vacc2_final_label.append(v_ann_59[i])
    
print(t_vacc2_final_label) 
print(len(t_vacc2_final_label))
t_vacc2_final_data = pd.DataFrame(data=tw_df_v2["text"], columns = ["text"])
t_vacc2_final_data.insert(1, 'label', t_vacc2_final_label)
print(t_vacc2_final_data)
# Out:
# [False, True, True, False, False, False, False, True, True, True, False, False, True, False, True, True, False, True, True, True, True, True, True, False, False, False, True, True, True, True, False, True, True, True, True, True, False, True, True, True, True, False, True, True, True, False, True, False, True, False, True, False, True, True, True, True, False, False, True, False, True, False, True, True, True, False, True, True, True, False, False, False, True, True, False, False, True, True, True, True, True, True, True, True, True, False, True, True, False, True, True, True, False, False, True, True, True, False, True, True, True, False, False, False, True, False, True, False, False, True, False, True, False, False, False, False, True, False, False, False, False, True, True, False, False, True, False, True, False, True, False, True, True, False, True, True, True, False, False, False, False, True, True, False, True, False, False, False, True, True, True, True, True, False, False, Tr
# ...

# %%
tw_df_l3.describe()
# Out:
#                                                      text annotation_91  \
# count                                                 300           300
# unique                                                299             2
# top     STUDIES SHOW MORPHINE MILLIGRAM EQUIVALENT (MM...         False
# freq                                                    2           289
#
#        annotation_85 annotation_86 annotation_87
# count            300           300           300
# unique             2             2             2
# top            False         False         False
# freq             283           296           274

# %%
#eliminate annotators which are not reliable 
#twitter lockdown file 3
#annotators 91, 85, 86, 87
if lock3_kappa_score_ann91 < 0.2:
    print("lock3_kappa_score_ann91 not reliable")
    
if lock3_kappa_score_ann85 < 0.2:
    print("lock3_kappa_score_ann85 not reliable")
    
if lock3_kappa_score_ann86 < 0.2:
    print("lock3_kappa_score_ann86 not reliable")
    
if lock3_kappa_score_ann87 < 0.2:
    print("lock3_kappa_score_ann87 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_l3 ={'ann91': lock3_kappa_score_ann91, 'ann85': lock3_kappa_score_ann85, 'ann87': lock3_kappa_score_ann87}
print(t_high_ann_l3)
#annotator with higher reliability
t_high_rel_ann_l3 = max(t_high_ann_l3, key=t_high_ann_l3.get)
print("High-reliability annotator is", t_high_rel_ann_l3)
# Out:
# lock3_kappa_score_ann86 not reliable
# {'ann91': 0.32835570175628914, 'ann85': 0.21786806677463708, 'ann87': 0.2611111700445586}
# High-reliability annotator is ann91

# %%
#considering only reliable annotators 
t_len_lock3 = len(tw_df_l3)
t_lock3_final_label = []
for i in range(0, t_len_lock3):
    count_true = 0
    count_false = 0
    if (l_ann_91[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_85[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (l_ann_87[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_lock3_final_label.append(True)
    elif (count_false > count_true):
        t_lock3_final_label.append(False)
    elif (count_true == count_false):
        t_lock3_final_label.append(l_ann_91[i])
    
print(t_lock3_final_label) 
print(len(t_lock3_final_label))
t_lock3_final_data = pd.DataFrame(data=tw_df_l3["text"], columns = ["text"])
t_lock3_final_data.insert(1, 'label', t_lock3_final_label)
print(t_lock3_final_data)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, Fa
# ...

# %%
#eliminate annotators which are not reliable 
#twitter masking file 3
#annotators 91, 85, 86, 87
if mask3_kappa_score_ann91 < 0.2:
    print("mask3_kappa_score_ann91 not reliable")
    
if mask3_kappa_score_ann85 < 0.2:
    print("mask3_kappa_score_ann85 not reliable")
    
if mask3_kappa_score_ann86 < 0.2:
    print("mask3_kappa_score_ann86 not reliable")
    
if mask3_kappa_score_ann87 < 0.2:
    print("mask3_kappa_score_ann87 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_m3 ={'ann91': mask3_kappa_score_ann91, 'ann85': mask3_kappa_score_ann85, 'ann86': mask3_kappa_score_ann86, 'ann87': mask3_kappa_score_ann87}
print(t_high_ann_m3)
#annotator with higher reliability
t_high_rel_ann_m3 = max(t_high_ann_m3, key=t_high_ann_m3.get)
print("High-reliability annotator is", t_high_rel_ann_m3)
# Out:
# {'ann91': 0.8319435933703723, 'ann85': 0.8032421828800219, 'ann86': 0.8556110752019936, 'ann87': 0.8140977640978617}
# High-reliability annotator is ann86

# %%
#considering only reliable annotators 
t_len_mask3 = len(tw_df_m3)
t_mask3_final_label = []
for i in range(0, t_len_mask3):
    count_true = 0
    count_false = 0
    if (m_ann_91[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_85[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_86[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (m_ann_87[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_mask3_final_label.append(True)
    elif (count_false > count_true):
        t_mask3_final_label.append(False)
    elif (count_true == count_false):
        t_mask3_final_label.append(m_ann_86[i])
    
print(t_mask3_final_label) 
print(len(t_mask3_final_label))
t_mask3_final_data = pd.DataFrame(data=tw_df_m3["text"], columns = ["text"])
t_mask3_final_data.insert(1, 'label', t_mask3_final_label)
print(t_mask3_final_data)
# Out:
# [False, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, True, True, False, False, False, False, True, False, False, False, False, True, False, True, False, False, False, False, False, True, True, False, False, False, True, False, False, False, True, False, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, True, True, False, False, True, False, False, False, True, False, False, False, False, True, True, True, False, False, False, False, False, True, True, False, False, False, True, True, False, False, False, False, True, False, Fa
# ...

# %%
#eliminate annotators which are not reliable 
#twitter vaccination file 3
#annotators 91, 85, 86, 87
if vacc3_kappa_score_ann91 < 0.2:
    print("vacc3_kappa_score_ann91 not reliable")
    
if vacc3_kappa_score_ann85 < 0.2:
    print("vacc3_kappa_score_ann85 not reliable")
    
if vacc3_kappa_score_ann86 < 0.2:
    print("vacc3_kappa_score_ann86 not reliable")
    
if vacc3_kappa_score_ann87 < 0.2:
    print("vacc3_kappa_score_ann87 not reliable")
    
#check high reliability annotator in case of tie

t_high_ann_v3 ={'ann91': vacc3_kappa_score_ann91, 'ann85': vacc3_kappa_score_ann85, 'ann86': vacc3_kappa_score_ann86, 'ann87': vacc3_kappa_score_ann87}
print(t_high_ann_v3)
#annotator with higher reliability
t_high_rel_ann_v3 = max(t_high_ann_v3, key=t_high_ann_v3.get)
print("High-reliability annotator is", t_high_rel_ann_v3)
# Out:
# {'ann91': 0.6676275621130413, 'ann85': 0.657906452588274, 'ann86': 0.6207114581266412, 'ann87': 0.6359096142185358}
# High-reliability annotator is ann91

# %%
#considering only reliable annotators 
t_len_vacc3 = len(tw_df_v3)
t_vacc3_final_label = []
for i in range(0, t_len_vacc3):
    count_true = 0
    count_false = 0
    if (v_ann_91[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_85[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_86[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (v_ann_87[i] == True):
        count_true = count_true + 1
    else:
        count_false = count_false + 1
    if (count_true > count_false):
        t_vacc3_final_label.append(True)
    elif (count_false > count_true):
        t_vacc3_final_label.append(False)
    elif (count_true == count_false):
        t_vacc3_final_label.append(v_ann_86[i])
    
print(t_vacc3_final_label) 
print(len(t_vacc3_final_label))
t_vacc3_final_data = pd.DataFrame(data=tw_df_v3["text"], columns = ["text"])
t_vacc3_final_data.insert(1, 'label', t_vacc3_final_label)
print(t_vacc3_final_data)
# Out:
# [True, False, True, True, False, True, True, False, True, True, False, False, True, True, True, False, False, False, True, False, False, True, True, False, True, False, False, True, True, True, True, False, False, True, True, False, False, True, True, False, True, True, True, True, True, False, True, True, False, False, False, True, False, True, True, True, True, True, True, True, True, True, False, False, False, True, True, True, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, True, True, False, True, False, True, False, False, False, False, True, True, True, False, False, True, True, True, True, True, True, False, False, False, True, True, False, False, False, False, False, True, False, True, False, False, False, False, False, True, True, False, False, True, False, False, False, True, False, False, True, True, False, False, False, False, False, True, False, True, True, False, True, True, True, True, True, Fals
# ...

# %%
#combine all change.org lockdown files
final_change_lock_file = pd.concat([lock0_final_data, lock1_final_data, lock2_final_data, lock3_final_data, lock4_final_data ])
print(final_change_lock_file)
final_change_lock_file.to_csv('/home/akshay/Desktop/Output_files/change_org_lockdown.csv')
# Out:
#                                                   text  label
# 0           Language Education in the Time of COVID-19  False
# 1                                   COVID-19 Test Kits  False
# 2                                   COVID 19 IN PRISON  False
# 3                                       Get Waled Home  False
# 4    Make pass/fail available for Mississippi State...  False
# 5    Governor Doug Burgum to Issue Mandatory Shelte...  False
# 6                        Early release due to covid 19  False
# 7    Medical professionals need protection and gear...  False
# 8    Save Gilroy Recreation - Theater, Aquatics, Pr...  False
# 9             Class of 2020 to get their certification  False
# 10   Calling for Disability- Inclusive Response to ...  False
# 11   Open the 2020-2021 School Year Traditionally i...  False
# 12   Save the Enhanced Nursery School Operating Gra...  False
# 13   Cancel the STAAR test for the 2020/2021 school...  False
# ...

# %%
#combine all change.org masking files
final_change_mask_file = pd.concat([mask0_final_data, mask1_final_data, mask2_final_data, mask3_final_data, mask4_final_data ])
print(final_change_mask_file)
final_change_lock_file.to_csv('/home/akshay/Desktop/Output_files/change_org_masking.csv')
# Out:
#                                                   text  label
# 0           Language Education in the Time of COVID-19  False
# 1                                   COVID-19 Test Kits  False
# 2                                   COVID 19 IN PRISON  False
# 3                                       Get Waled Home  False
# 4    Make pass/fail available for Mississippi State...  False
# 5    Governor Doug Burgum to Issue Mandatory Shelte...  False
# 6                        Early release due to covid 19  False
# 7    Medical professionals need protection and gear...  False
# 8    Save Gilroy Recreation - Theater, Aquatics, Pr...  False
# 9             Class of 2020 to get their certification  False
# 10   Calling for Disability- Inclusive Response to ...  False
# 11   Open the 2020-2021 School Year Traditionally i...  False
# 12   Save the Enhanced Nursery School Operating Gra...  False
# 13   Cancel the STAAR test for the 2020/2021 school...  False
# ...

# %%
#combine all change.org vaccination files
final_change_vacc_file = pd.concat([vacc0_final_data, vacc1_final_data, vacc2_final_data, vacc3_final_data, vacc4_final_data ])
print(final_change_vacc_file)
final_change_vacc_file.to_csv('/home/akshay/Desktop/Output_files/change_org_vaccination.csv')
# Out:
#                                                   text  label
# 0           Language Education in the Time of COVID-19  False
# 1                                   COVID-19 Test Kits  False
# 2                                   COVID 19 IN PRISON  False
# 3                                       Get Waled Home  False
# 4    Make pass/fail available for Mississippi State...  False
# 5    Governor Doug Burgum to Issue Mandatory Shelte...  False
# 6                        Early release due to covid 19  False
# 7    Medical professionals need protection and gear...   True
# 8    Save Gilroy Recreation - Theater, Aquatics, Pr...  False
# 9             Class of 2020 to get their certification  False
# 10   Calling for Disability- Inclusive Response to ...  False
# 11   Open the 2020-2021 School Year Traditionally i...  False
# 12   Save the Enhanced Nursery School Operating Gra...  False
# 13   Cancel the STAAR test for the 2020/2021 school...  False
# ...

# %%
#combine all twitter lockdown files
t_final_change_lock_file = pd.concat([t_lock0_final_data, t_lock1_final_data, t_lock2_final_data, t_lock3_final_data ])
print(t_final_change_lock_file)
t_final_change_lock_file.to_csv('/home/akshay/Desktop/Output_files/twitter_lockdown.csv')
# Out:
#                                                   text  label
# 0    Putin After Announcing #CovidVaccine #Russian ...  False
# 1    Courtesy: WA! #WhatsApp #COVID #CovidVaccine h...  False
# 2    4 of the vaccines Jared bought are expected to...  False
# 3    One day you will realize CDC Guidelines magica...  False
# 4    Im far from lying.  Current CDC guidelines is ...  False
# 5    Russia’s Covid vaccine ‘Sputnik-V’ might be re...  False
# 6    I don’t see masks. In fact, my child was there...  False
# 7    I am fully vaccinated, unless CDC guidelines c...  False
# 8    we ask every single person that walks in so we...  False
# 9    will the sense touch 40k after a #CovidVaccine...  False
# 10   Health ministry approval Covid vaccine in Russ...  False
# 11   10 Days of Onam names | in kerala https://t.co...  False
# 12   amazing review and insights from #vaccine expe...  False
# 13   Pretty sure the only people wearing masks righ...  False
# ...

# %%
#combine all twitter masking files
t_final_change_mask_file = pd.concat([t_mask0_final_data, t_mask1_final_data, t_mask2_final_data, t_mask3_final_data ])
print(t_final_change_mask_file)
t_final_change_mask_file.to_csv('/home/akshay/Desktop/Output_files/twitter_masking.csv')
# Out:
#                                                   text  label
# 0    Putin After Announcing #CovidVaccine #Russian ...  False
# 1    Courtesy: WA! #WhatsApp #COVID #CovidVaccine h...  False
# 2    4 of the vaccines Jared bought are expected to...  False
# 3    One day you will realize CDC Guidelines magica...  False
# 4    Im far from lying.  Current CDC guidelines is ...   True
# 5    Russia’s Covid vaccine ‘Sputnik-V’ might be re...  False
# 6    I don’t see masks. In fact, my child was there...   True
# 7    I am fully vaccinated, unless CDC guidelines c...   True
# 8    we ask every single person that walks in so we...   True
# 9    will the sense touch 40k after a #CovidVaccine...  False
# 10   Health ministry approval Covid vaccine in Russ...  False
# 11   10 Days of Onam names | in kerala https://t.co...  False
# 12   amazing review and insights from #vaccine expe...  False
# 13   Pretty sure the only people wearing masks righ...   True
# ...

# %%
#combine all twitter vaccination files
t_final_change_vacc_file = pd.concat([t_vacc0_final_data, t_vacc1_final_data, t_vacc2_final_data, t_vacc3_final_data ])
print(t_final_change_vacc_file)
t_final_change_vacc_file.to_csv('/home/akshay/Desktop/Output_files/twitter_vaccination.csv')
# Out:
#                                                   text  label
# 0    Putin After Announcing #CovidVaccine #Russian ...   True
# 1    Courtesy: WA! #WhatsApp #COVID #CovidVaccine h...   True
# 2    4 of the vaccines Jared bought are expected to...   True
# 3    One day you will realize CDC Guidelines magica...  False
# 4    Im far from lying.  Current CDC guidelines is ...   True
# 5    Russia’s Covid vaccine ‘Sputnik-V’ might be re...   True
# 6    I don’t see masks. In fact, my child was there...  False
# 7    I am fully vaccinated, unless CDC guidelines c...   True
# 8    we ask every single person that walks in so we...   True
# 9    will the sense touch 40k after a #CovidVaccine...   True
# 10   Health ministry approval Covid vaccine in Russ...   True
# 11   10 Days of Onam names | in kerala https://t.co...  False
# 12   amazing review and insights from #vaccine expe...   True
# 13   Pretty sure the only people wearing masks righ...   True
# ...
